# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('../driver/chromedriver')
driver.get('http://www.opinet.co.kr/searRgSelect.do')

# %%
gu_list_raw = driver.find_element_by_xpath("""//*[@id="DONG_NM"]""")
gu_list = gu_list_raw.find_elements_by_tag_name('option')

# %%
gu_names = [option.get_attribute('value') for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['가좌동',
#  '강매동',
#  '고봉동',
#  '고양동',
#  '관산동',
#  '구산동',
#  '내곡동',
#  '내유동',
#  '능곡동',
#  '대덕동',
#  '대자동',
#  '대장동',
#  '대화동',
#  '덕은동',
#  '덕이동',
#  '도내동',
#  '동산동',
#  '마두1동',
#  '마두2동',
#  '마두동',
#  '문봉동',
#  '백석동',
#  '법곳동',
#  '벽제동',
#  '북한동',
#  '사리현동',
#  '산황동',
#  '삼송동',
#  '선유동',
#  '설문동',
#  '성사1동',
#  '성사2동',
#  '성사동',
#  '성석동',
#  '송산동',
#  '송포동',
#  '식사동',
#  '신도동',
#  '신원동',
#  '신평동',
#  '오금동',
#  '용두동',
#  '원당동',
#  '원신동',
#  '원흥동',
#  '일산1동',
#  '일산2동',
#  '일산3동',
#  '일산동',
#  '장항1동',
#  '장항2동',
#  '장항동',
#  '정발산동',
#  '주교동',
#  '주엽1동',
#  '주엽2동',
#  '주엽동',
#  '중산동',
#  '지영동',
#  '지축동',
#  '창릉동',
#  '탄현동',
#  '토당동',
#  '풍동',
#  '풍산동',
#  '행신1동',
#  '행신2동',
#  '행신3동',
#  '행신동',
#  '행주내동',
#  '행주동',
#  '행주외동',
#  '향동동',
#  '현천동',
#  '화전동',
#  '화정1동',
#  '화정2동',
#  '화정동',
#  '효자동',
#  '흥도동']

# %%
element = driver.find_element_by_id('DONG_NM')
element.send_keys(gu_names[0])

# %%
xpath = """//*[@id="searRgSelect"]"""
element_sel_gu = driver.find_element_by_xpath(xpath).click()

# %%
xpath = """//*[@id="glopopd_excel"]"""
element_get_excel = driver.find_element_by_xpath(xpath).click()

# %%
import time
from tqdm import tqdm_notebook

for gu in tqdm_notebook(gu_names):
    element = driver.find_element_by_id('DONG_NM')
    element.send_keys(gu)
    
    time.sleep(2)
    
    xpath = """//*[@id="searRgSelect"]"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()

    time.sleep(1)

    xpath = """//*[@id="glopopd_excel"]"""
    element_get_excel = driver.find_element_by_xpath(xpath).click()

    time.sleep(1)
# Out:
# HBox(children=(IntProgress(value=0, max=80), HTML(value='')))

# %%
driver.close()

# %%
import pandas as pd
from glob import glob

# %%
glob('../data/data/지역*.xls')
# Out:
# ['../data/data\\지역_위치별(주유소) (1).xls',
#  '../data/data\\지역_위치별(주유소) (10).xls',
#  '../data/data\\지역_위치별(주유소) (11).xls',
#  '../data/data\\지역_위치별(주유소) (12).xls',
#  '../data/data\\지역_위치별(주유소) (13).xls',
#  '../data/data\\지역_위치별(주유소) (14).xls',
#  '../data/data\\지역_위치별(주유소) (15).xls',
#  '../data/data\\지역_위치별(주유소) (16).xls',
#  '../data/data\\지역_위치별(주유소) (17).xls',
#  '../data/data\\지역_위치별(주유소) (18).xls',
#  '../data/data\\지역_위치별(주유소) (19).xls',
#  '../data/data\\지역_위치별(주유소) (2).xls',
#  '../data/data\\지역_위치별(주유소) (20).xls',
#  '../data/data\\지역_위치별(주유소) (21).xls',
#  '../data/data\\지역_위치별(주유소) (22).xls',
#  '../data/data\\지역_위치별(주유소) (23).xls',
#  '../data/data\\지역_위치별(주유소) (24).xls',
#  '../data/data\\지역_위치별(주유소) (25).xls',
#  '../data/data\\지역_위치별(주유소) (26).xls',
#  '../data/data\\지역_위치별(주유소) (27).xls',
#  '../data/data\\지역_위치별(주유소) (28).xls',
#  '../data/data\\지역_위치별(주유소) (29).xls',
#  '../data/data\\지역_위치별(주유소) (3).xls',
#  '../data/data\\지역_위치별(주유소) (30).xls',
#  '../data/data\\지역_위치별(주유소) (31).xls',
#  '../data/data\\지역_위치별(주유소) (32).xls',
#  '../data/data\\지역_위치별(주유소) (33).xls',
#  '../data/data\\지역_위치별(주유소) (34).xls',
#  '../data/data\\지역_위치별(주유소) (35).xls',
#  '../data/data\\지역_위치별(주유소) (36).xls',
#  '../data/data\\지역_위치별(주유소) (37).xls',
#  '../data/data\\지역_위치별(주유소) (38).xls',
#  '../data/data\\지역_위치별(주유소) (39).xls',
#  '../data/data\\지역_위치별(주유소) (4).xls',
#  '../data/data\\지역_위치별(주유소) (40).xls',
#  '../data/data\\지역_위치별(주유소) (41).xls',
#  '../data/data\\지역_위치별(주유소) (42).xls',
#  '../data/data\\지역_위치별(주유소) (43).xls',
#  '../data/data\\지역_위치별(주유소) (44).xls',
#  '../data/data\\지역_위치별(주유소) (45).xls',
#  '../data/data\\지역_위치별(주유소) (46).xls',
#  '../data/data\\지역_위치별(주유소) (47).xls',
#  '../data/data\\지역_위치별(주유소) (48).xls',
#  '../data/data\\지역_위치별(주유소) (49).xls',
#  '../data/data\\지역_위치별(주유소) (5).xls',
#  '../data/data\\지역_위치별(주유소) (50).xls',
#  '../data/data\\지역_위치별(주유소) (51).xls',
#  '../data/data\\지역_위치별(주유소) (52).xls',
#  '../data/data\\지역_위치별(주유소) (53).xls',
#  '../data/data\\지역_위치별(주유소) (54).xls',
#  '../data/data\\지역_위치별(주유소) (55).xls',
#  '../data/data\\지역_위치별(주유소) (56).xls',
#  '../data/data\\지역_위치별(주유소) (57).xls',
#  '../data/data\\지역_위치별(주유소) (58).xls',
#  '../data/data\\지역_위치별(주유소) (59).xls',
#  '../data/data\\지역_위치별(주유소) (6).xls',
#  '../data/data\\지역_위치별(주유소) (60).xls',
#  '../data/data\\지역_위치별(주유소) (61).xls',
#  '../data/data\\지역_위치별(주유소) (62).xls',
#  '../data/data\\지역_위치별(주유소) (63).xls',
#  '../data/data\\지역_위치별(주유소) (64).xls',
#  '../data/data\\지역_위치별(주유소) (65).xls',
#  '../data/data\\지역_위치별(주유소) (66).xls',
#  '../data/data\\지역_위치별(주유소) (67).xls',
#  '../data/data\\지역_위치별(주유소) (68).xls',
#  '../data/data\\지역_위치별(주유소) (69).xls',
#  '../data/data\\지역_위치별(주유소) (7).xls',
#  '../data/data\\지역_위치별(주유소) (70).xls',
#  '../data/data\\지역_위치별(주유소) (71).xls',
#  '../data/data\\지역_위치별(주유소) (72).xls',
#  '../data/data\\지역_위치별(주유소) (73).xls',
#  '../data/data\\지역_위치별(주유소) (74).xls',
#  '../data/data\\지역_위치별(주유소) (75).xls',
#  '../data/data\\지역_위치별(주유소) (76).xls',
#  '../data/data\\지역_위치별(주유소) (77).xls',
#  '../data/data\\지역_위치별(주유소) (78).xls',
#  '../data/data\\지역_위치별(주유소) (79).xls',
#  '../data/data\\지역_위치별(주유소) (8).xls',
#  '../data/data\\지역_위치별(주유소) (9).xls',
#  '../data/data\\지역_위치별(주유소).xls']

# %%
station_files = glob('../data/data/지역*.xls')
station_files
# Out:
# ['../data/data\\지역_위치별(주유소) (1).xls',
#  '../data/data\\지역_위치별(주유소) (10).xls',
#  '../data/data\\지역_위치별(주유소) (11).xls',
#  '../data/data\\지역_위치별(주유소) (12).xls',
#  '../data/data\\지역_위치별(주유소) (13).xls',
#  '../data/data\\지역_위치별(주유소) (14).xls',
#  '../data/data\\지역_위치별(주유소) (15).xls',
#  '../data/data\\지역_위치별(주유소) (16).xls',
#  '../data/data\\지역_위치별(주유소) (17).xls',
#  '../data/data\\지역_위치별(주유소) (18).xls',
#  '../data/data\\지역_위치별(주유소) (19).xls',
#  '../data/data\\지역_위치별(주유소) (2).xls',
#  '../data/data\\지역_위치별(주유소) (20).xls',
#  '../data/data\\지역_위치별(주유소) (21).xls',
#  '../data/data\\지역_위치별(주유소) (22).xls',
#  '../data/data\\지역_위치별(주유소) (23).xls',
#  '../data/data\\지역_위치별(주유소) (24).xls',
#  '../data/data\\지역_위치별(주유소) (25).xls',
#  '../data/data\\지역_위치별(주유소) (26).xls',
#  '../data/data\\지역_위치별(주유소) (27).xls',
#  '../data/data\\지역_위치별(주유소) (28).xls',
#  '../data/data\\지역_위치별(주유소) (29).xls',
#  '../data/data\\지역_위치별(주유소) (3).xls',
#  '../data/data\\지역_위치별(주유소) (30).xls',
#  '../data/data\\지역_위치별(주유소) (31).xls',
#  '../data/data\\지역_위치별(주유소) (32).xls',
#  '../data/data\\지역_위치별(주유소) (33).xls',
#  '../data/data\\지역_위치별(주유소) (34).xls',
#  '../data/data\\지역_위치별(주유소) (35).xls',
#  '../data/data\\지역_위치별(주유소) (36).xls',
#  '../data/data\\지역_위치별(주유소) (37).xls',
#  '../data/data\\지역_위치별(주유소) (38).xls',
#  '../data/data\\지역_위치별(주유소) (39).xls',
#  '../data/data\\지역_위치별(주유소) (4).xls',
#  '../data/data\\지역_위치별(주유소) (40).xls',
#  '../data/data\\지역_위치별(주유소) (41).xls',
#  '../data/data\\지역_위치별(주유소) (42).xls',
#  '../data/data\\지역_위치별(주유소) (43).xls',
#  '../data/data\\지역_위치별(주유소) (44).xls',
#  '../data/data\\지역_위치별(주유소) (45).xls',
#  '../data/data\\지역_위치별(주유소) (46).xls',
#  '../data/data\\지역_위치별(주유소) (47).xls',
#  '../data/data\\지역_위치별(주유소) (48).xls',
#  '../data/data\\지역_위치별(주유소) (49).xls',
#  '../data/data\\지역_위치별(주유소) (5).xls',
#  '../data/data\\지역_위치별(주유소) (50).xls',
#  '../data/data\\지역_위치별(주유소) (51).xls',
#  '../data/data\\지역_위치별(주유소) (52).xls',
#  '../data/data\\지역_위치별(주유소) (53).xls',
#  '../data/data\\지역_위치별(주유소) (54).xls',
#  '../data/data\\지역_위치별(주유소) (55).xls',
#  '../data/data\\지역_위치별(주유소) (56).xls',
#  '../data/data\\지역_위치별(주유소) (57).xls',
#  '../data/data\\지역_위치별(주유소) (58).xls',
#  '../data/data\\지역_위치별(주유소) (59).xls',
#  '../data/data\\지역_위치별(주유소) (6).xls',
#  '../data/data\\지역_위치별(주유소) (60).xls',
#  '../data/data\\지역_위치별(주유소) (61).xls',
#  '../data/data\\지역_위치별(주유소) (62).xls',
#  '../data/data\\지역_위치별(주유소) (63).xls',
#  '../data/data\\지역_위치별(주유소) (64).xls',
#  '../data/data\\지역_위치별(주유소) (65).xls',
#  '../data/data\\지역_위치별(주유소) (66).xls',
#  '../data/data\\지역_위치별(주유소) (67).xls',
#  '../data/data\\지역_위치별(주유소) (68).xls',
#  '../data/data\\지역_위치별(주유소) (69).xls',
#  '../data/data\\지역_위치별(주유소) (7).xls',
#  '../data/data\\지역_위치별(주유소) (70).xls',
#  '../data/data\\지역_위치별(주유소) (71).xls',
#  '../data/data\\지역_위치별(주유소) (72).xls',
#  '../data/data\\지역_위치별(주유소) (73).xls',
#  '../data/data\\지역_위치별(주유소) (74).xls',
#  '../data/data\\지역_위치별(주유소) (75).xls',
#  '../data/data\\지역_위치별(주유소) (76).xls',
#  '../data/data\\지역_위치별(주유소) (77).xls',
#  '../data/data\\지역_위치별(주유소) (78).xls',
#  '../data/data\\지역_위치별(주유소) (79).xls',
#  '../data/data\\지역_위치별(주유소) (8).xls',
#  '../data/data\\지역_위치별(주유소) (9).xls',
#  '../data/data\\지역_위치별(주유소).xls']

# %%
tmp_raw = []

for file_name in station_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
    
station_raw = pd.concat(tmp_raw)

# %%
station_raw.head()
# Out:
#     지역             상호                            주소      상표          전화번호  \
# 0  경기도   대신석유(주)대자주유소          경기도 고양시 덕양구  통일로 499   SK에너지  031-969-5186
# 1  경기도         고양동주유소      경기 고양시 덕양구 동헌로 187 (대자동)   GS칼텍스  031-969-5189
# 0  경기도        농협하나로유통   경기도 고양시 일산서구  대화로 362 (대화동)  NH-OIL  031-910-9111
# 1  경기도  sj오일(주) 일산주유소  경기도 고양시 일산서구  고양대로 535 (대화동)   GS칼텍스  031-918-5154
# 0  경기도       제1자유로주유소     경기 고양시 덕양구 자유로 94,  (덕은동)   GS칼텍스  02-3158-0707
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    Y     -  1564  1364     -
# 1    N     -  1689  1389  1000
# 0    Y     -  1559  1359   950
# 1    N  1875  1645  1445   990
# 0    Y  1897  1587  1397   970

# %%
station_raw.describe()
# Out:
#          지역     상호                        주소     상표          전화번호 셀프여부 고급휘발유  \
# count   149    149                       149    149           149  149   149
# unique    1    148                       149      7           149    2    26
# top     경기도  동원주유소  경기 고양시 덕양구 호수로 237 (내곡동)  SK에너지  031-919-5182    N     -
# freq    149      2                         1     46             1   77   118
#
#          휘발유    경유 실내등유
# count    149   149  149
# unique    63    68   30
# top     1557  1357    -
# freq      12     9   71

# %%
stations = pd.DataFrame({'Oil_store':station_raw['상호'], '주소':station_raw['주소'], '가격':station_raw['휘발유'], 
                        '셀프':station_raw['셀프여부'], '상표':station_raw['상표']})
stations.head()
# Out:
#        Oil_store                            주소    가격 셀프      상표
# 0   대신석유(주)대자주유소          경기도 고양시 덕양구  통일로 499  1564  Y   SK에너지
# 1         고양동주유소      경기 고양시 덕양구 동헌로 187 (대자동)  1689  N   GS칼텍스
# 0        농협하나로유통   경기도 고양시 일산서구  대화로 362 (대화동)  1559  Y  NH-OIL
# 1  sj오일(주) 일산주유소  경기도 고양시 일산서구  고양대로 535 (대화동)  1645  N   GS칼텍스
# 0       제1자유로주유소     경기 고양시 덕양구 자유로 94,  (덕은동)  1587  Y   GS칼텍스

# %%
stations['구']=[eachAddress.split()[2] for eachAddress in stations['주소']]
stations.head()
# Out:
#        Oil_store                            주소    가격 셀프      상표     구
# 0   대신석유(주)대자주유소          경기도 고양시 덕양구  통일로 499  1564  Y   SK에너지   덕양구
# 1         고양동주유소      경기 고양시 덕양구 동헌로 187 (대자동)  1689  N   GS칼텍스   덕양구
# 0        농협하나로유통   경기도 고양시 일산서구  대화로 362 (대화동)  1559  Y  NH-OIL  일산서구
# 1  sj오일(주) 일산주유소  경기도 고양시 일산서구  고양대로 535 (대화동)  1645  N   GS칼텍스  일산서구
# 0       제1자유로주유소     경기 고양시 덕양구 자유로 94,  (덕은동)  1587  Y   GS칼텍스   덕양구

# %%
stations['구'].unique()
# Out:
# array(['덕양구', '일산서구', '일산동구', '고양대로'], dtype=object)

# %%
stations.loc[stations['구']=='서울특별시', '구'] = '성동구'
stations['구'].unique()
# Out:
# array(['덕양구', '일산서구', '일산동구', '고양대로'], dtype=object)

# %%
stations[stations['구']=='고양대로']
# Out:
#   Oil_store                         주소    가격 셀프     상표     구
# 0     동원주유소  경기 고양시일산서구 고양대로 717 (일산동)  1598  Y  SK에너지  고양대로

# %%
stations.loc[stations['구']=='고양대로', '구'] = '일산서구'
stations['구'].unique()
# Out:
# array(['덕양구', '일산서구', '일산동구'], dtype=object)

# %%
stations['가격'].unique()
# Out:
# array([1564, 1689, 1559, 1645, 1587, 1843, 1549, 1577, 1589, 1597, 1619,
#        1620, 1557, 1569, '1567', '-', 1599, 1637, 1565, 1575, '1564',
#        '1569', '1587', '1606', 1598, '1557', 1628, 1576, 1617, 1555, 1567,
#        1586, 1643, 1578, 1595, 1615, 1574, 1629, 1646, 1675, 1572, 1562,
#        1698, 1537, 1553, 1545, 1547, 1579, 1699, 1585, 1948, '1575',
#        '1599', '1625', '1947', 1653, 1613, 1679, 1641, 1799, 1558, 1669,
#        1618], dtype=object)

# %%
stations[stations['가격']=='-']
# Out:
#   Oil_store                           주소 가격 셀프     상표     구
# 2    우리들주유소    경기 고양시 일산동구 고봉로 799 (설문동)  -  N  GS칼텍스  일산동구
# 5     정미주유소  경기도 고양시 덕양구  호국로 1827 (고양동)  -  N  GS칼텍스   덕양구
# 6     상일주유소     경기 고양시 덕양구 혜음로 240 (벽제동)  -  N  SK에너지   덕양구
# 2   유양제2주유소          경기 고양시 일산동구 고봉로 719  -  N  SK에너지  일산동구
# 4   장항IC주유소   경기도 고양시 일산동구  백마로 54 (장항동)  -  Y  GS칼텍스  일산동구

# %%
stations = stations[stations['가격'] != '-']
stations['가격'].describe()
# Out:
# count      144
# unique      62
# top       1557
# freq        12
# Name: 가격, dtype: int64

# %%
stations['가격'] = [float(value) for value in stations['가격']]

# %%
stations['가격'].describe()
# Out:
# count     144.000000
# mean     1597.347222
# std        60.514267
# min      1537.000000
# 25%      1564.000000
# 50%      1582.000000
# 75%      1600.750000
# max      1948.000000
# Name: 가격, dtype: float64

# %%
stations.reset_index(inplace=True)
stations.head()
# Out:
#    index      Oil_store                            주소      가격 셀프      상표     구
# 0      0   대신석유(주)대자주유소          경기도 고양시 덕양구  통일로 499  1564.0  Y   SK에너지   덕양구
# 1      1         고양동주유소      경기 고양시 덕양구 동헌로 187 (대자동)  1689.0  N   GS칼텍스   덕양구
# 2      0        농협하나로유통   경기도 고양시 일산서구  대화로 362 (대화동)  1559.0  Y  NH-OIL  일산서구
# 3      1  sj오일(주) 일산주유소  경기도 고양시 일산서구  고양대로 535 (대화동)  1645.0  N   GS칼텍스  일산서구
# 4      0       제1자유로주유소     경기 고양시 덕양구 자유로 94,  (덕은동)  1587.0  Y   GS칼텍스   덕양구

# %%
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 6 columns):
# Oil_store    144 non-null object
# 주소           144 non-null object
# 가격           144 non-null float64
# 셀프           144 non-null object
# 상표           144 non-null object
# 구            144 non-null object
# dtypes: float64(1), object(5)
# memory usage: 6.8+ KB

# %%
stations.describe()
# Out:
#                 가격
# count   144.000000
# mean   1597.347222
# std      60.514267
# min    1537.000000
# 25%    1564.000000
# 50%    1582.000000
# 75%    1600.750000
# max    1948.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform
path = 'C:/Windows/Fonts/malgun.ttf'
from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family = font_name)
else:
    print('Unknown system... sorry~~~')

# %%
stations.boxplot(column='가격', by='셀프', figsize=(12,8))

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격', hue='셀프',data=stations,palette='Set3' )
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='상표', y='가격',data=stations,palette='Set3' )
sns.swarmplot(x='상표',y='가격',data=stations, color='.6')
plt.show()

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)

# %%
stations.sort_values(by='가격', ascending=False).head()
# Out:
#        Oil_store                          주소      가격 셀프     상표     구
# 88    사우디제 7 주유소    경기 고양시 일산동구 백마로 37 (장항동)  1948.0  N  SK에너지  일산동구
# 94        오렌지주유소    경기 고양시 일산동구 백마로 49 (장항동)  1947.0  N  GS칼텍스  일산동구
# 5    GS칼텍스 상암주유소     경기 고양시 덕양구 자유로 38 (덕은동)  1843.0  N  GS칼텍스   덕양구
# 126        삼일주유소     경기 고양시 덕양구 지도로 15 (토당동)  1799.0  N  SK에너지   덕양구
# 82     self으뜸주유소  경기 고양시 일산서구 고양대로 632 (일산동)  1699.0  Y  SK에너지  일산서구

# %%
stations.sort_values(by='가격').head()
# Out:
#           Oil_store                                주소      가격 셀프      상표     구
# 74   J＆S(주)원흥,원당동지점         경기 고양시 덕양구 호국로 1113 (원당동)  1537.0  Y  현대오일뱅크   덕양구
# 136          어울림주유소  경기도 고양시 덕양구 충장로 407 (화정동 188-20)  1545.0  Y   알뜰주유소   덕양구
# 79         너멍골알뜰주유소               경기 고양시 덕양구 호국로 1259  1545.0  Y   알뜰주유소   덕양구
# 80      (주)원흥 원흥동지점         경기 고양시 덕양구 서오릉로 712 (원흥동)  1547.0  Y  현대오일뱅크   덕양구
# 6             풍년에너지        경기도 고양시 일산서구  덕이로 94 (덕이동)  1549.0  Y   S-OIL  일산서구

# %%
import numpy as np
gu_data = pd.pivot_table(stations, index=['구'], values=['가격'], aggfunc=np.mean)
gu_data.head()
# Out:
#                가격
# 구
# 덕양구   1595.205882
# 일산동구  1604.222222
# 일산서구  1592.064516

# %%
geo_path = '../data/02. skorea_municipalities_geo_simple.json'
geo_data = json.load(open(geo_path, encoding='utf-8'))

map = folium.Map(location=[37.5502,126.982], zoom_start=10.5, tiles = 'Stamen Toner')
map.choropleth(geo_data = geo_data, data= gu_data, columns=[gu_data.index, '가격'], fill_color ='PuRd', key_on = 'feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oil_price_top10 = stations.sort_values(by='가격', ascending=False).head(10)
oil_price_top10
# Out:
#        Oil_store                          주소      가격 셀프     상표     구
# 88    사우디제 7 주유소    경기 고양시 일산동구 백마로 37 (장항동)  1948.0  N  SK에너지  일산동구
# 94        오렌지주유소    경기 고양시 일산동구 백마로 49 (장항동)  1947.0  N  GS칼텍스  일산동구
# 5    GS칼텍스 상암주유소     경기 고양시 덕양구 자유로 38 (덕은동)  1843.0  N  GS칼텍스   덕양구
# 126        삼일주유소     경기 고양시 덕양구 지도로 15 (토당동)  1799.0  N  SK에너지   덕양구
# 82     self으뜸주유소  경기 고양시 일산서구 고양대로 632 (일산동)  1699.0  Y  SK에너지  일산서구
# 132        처음주유소    경기 고양시 덕양구 중앙로 209 (화전동)  1699.0  N  S-OIL   덕양구
# 73         관산주유소  경기도 고양시 덕양구  통일로 790 (관산동)  1698.0  N  GS칼텍스   덕양구
# 118        행신주유소    경기 고양시 덕양구 소원로 279 (행신동)  1698.0  N  SK에너지   덕양구
# 1         고양동주유소    경기 고양시 덕양구 동헌로 187 (대자동)  1689.0  N  GS칼텍스   덕양구
# 100       효자로주유소    경기 고양시 덕양구 일영로 127 (지축동)  1679.0  N  S-OIL   덕양구

# %%
oil_price_bottom10 = stations.sort_values(by='가격', ascending=False).tail(10)
oil_price_bottom10
# Out:
#           Oil_store                                주소      가격 셀프      상표     구
# 110       (주)원흥풍동지점       경기도 고양시 일산동구  무궁화로 299 (풍동)  1557.0  Y  현대오일뱅크  일산동구
# 40        주)원흥고양동지점        경기도 고양시 덕양구 호국로 1789 (고양동)  1557.0  N  현대오일뱅크   덕양구
# 46          성석셀프주유소        경기도 고양시 일산동구  성현로 58 (성석동)  1555.0  Y  현대오일뱅크  일산동구
# 75      SK부광주유소 원당점        경기도 고양시 덕양구  원당로 433 (원당동)  1553.0  N   SK에너지   덕양구
# 7     (주)주연덕이 셀프주유소     경기도 고양시 일산서구 덕이로292번길 13(덕이동)  1549.0  Y  현대오일뱅크  일산서구
# 6             풍년에너지        경기도 고양시 일산서구  덕이로 94 (덕이동)  1549.0  Y   S-OIL  일산서구
# 80      (주)원흥 원흥동지점         경기 고양시 덕양구 서오릉로 712 (원흥동)  1547.0  Y  현대오일뱅크   덕양구
# 136          어울림주유소  경기도 고양시 덕양구 충장로 407 (화정동 188-20)  1545.0  Y   알뜰주유소   덕양구
# 79         너멍골알뜰주유소               경기 고양시 덕양구 호국로 1259  1545.0  Y   알뜰주유소   덕양구
# 74   J＆S(주)원흥,원당동지점         경기 고양시 덕양구 호국로 1113 (원당동)  1537.0  Y  현대오일뱅크   덕양구

# %%
gmaps_key = 'AIzaSyBca53USUfP5qWg91BhtfUO0RqZMU3eIHc'
gmaps = googlemaps.Client(key=gmaps_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = str(oil_price_top10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print('Here is nan!')
        
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#        Oil_store                          주소      가격 셀프     상표     구  \
# 88    사우디제 7 주유소    경기 고양시 일산동구 백마로 37 (장항동)  1948.0  N  SK에너지  일산동구
# 94        오렌지주유소    경기 고양시 일산동구 백마로 49 (장항동)  1947.0  N  GS칼텍스  일산동구
# 5    GS칼텍스 상암주유소     경기 고양시 덕양구 자유로 38 (덕은동)  1843.0  N  GS칼텍스   덕양구
# 126        삼일주유소     경기 고양시 덕양구 지도로 15 (토당동)  1799.0  N  SK에너지   덕양구
# 82     self으뜸주유소  경기 고양시 일산서구 고양대로 632 (일산동)  1699.0  Y  SK에너지  일산서구
# 132        처음주유소    경기 고양시 덕양구 중앙로 209 (화전동)  1699.0  N  S-OIL   덕양구
# 73         관산주유소  경기도 고양시 덕양구  통일로 790 (관산동)  1698.0  N  GS칼텍스   덕양구
# 118        행신주유소    경기 고양시 덕양구 소원로 279 (행신동)  1698.0  N  SK에너지   덕양구
# 1         고양동주유소    경기 고양시 덕양구 동헌로 187 (대자동)  1689.0  N  GS칼텍스   덕양구
# 100       효자로주유소    경기 고양시 덕양구 일영로 127 (지축동)  1679.0  N  S-OIL   덕양구
#
#            lat         lng
# 88   37.643271  126.760209
# 94   37.643748  126.760637
# 5    37.578947  126.859694
# 126  37.618538  126.824224
# 82   37.683794  126.769119
# 132  37.605233  126.866950
# 73   37.615199  126.925920
# 118  37.616014  126.838274
# 1    37.707919  126.877351
# 100  37.657498  126.919943

# %%
lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index):
    try:
        tmp_add = str(oil_price_bottom10['주소'][n]).split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print('Here is nan!')
        
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#           Oil_store                                주소      가격 셀프      상표  \
# 110       (주)원흥풍동지점       경기도 고양시 일산동구  무궁화로 299 (풍동)  1557.0  Y  현대오일뱅크
# 40        주)원흥고양동지점        경기도 고양시 덕양구 호국로 1789 (고양동)  1557.0  N  현대오일뱅크
# 46          성석셀프주유소        경기도 고양시 일산동구  성현로 58 (성석동)  1555.0  Y  현대오일뱅크
# 75      SK부광주유소 원당점        경기도 고양시 덕양구  원당로 433 (원당동)  1553.0  N   SK에너지
# 7     (주)주연덕이 셀프주유소     경기도 고양시 일산서구 덕이로292번길 13(덕이동)  1549.0  Y  현대오일뱅크
# 6             풍년에너지        경기도 고양시 일산서구  덕이로 94 (덕이동)  1549.0  Y   S-OIL
# 80      (주)원흥 원흥동지점         경기 고양시 덕양구 서오릉로 712 (원흥동)  1547.0  Y  현대오일뱅크
# 136          어울림주유소  경기도 고양시 덕양구 충장로 407 (화정동 188-20)  1545.0  Y   알뜰주유소
# 79         너멍골알뜰주유소               경기 고양시 덕양구 호국로 1259  1545.0  Y   알뜰주유소
# 74   J＆S(주)원흥,원당동지점         경기 고양시 덕양구 호국로 1113 (원당동)  1537.0  Y  현대오일뱅크
#
#         구        lat         lng
# 110  일산동구  37.675320  126.793171
# 40    덕양구  37.676286  126.874897
# 46   일산동구  37.707906  126.792820
# 75    덕양구  37.687056  126.850403
# 7    일산서구  37.704098  126.733587
# 6    일산서구  37.691628  126.749538
# 80    덕양구  37.640001  126.865970
# 136   덕양구  37.638642  126.840782
# 79    덕양구  37.676286  126.874897
# 74    덕양구  37.676286  126.874897

# %%
map = folium.Map(location=[37.65, 126.832], zoom_start=12)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]],
                           radius=15, color='#CD3181', fill_color = '#CD3181', fill=True).add_to(map)

for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]):
        folium.CircleMarker([oil_price_bottom10['lat'][n], oil_price_bottom10['lng'][n]],
                           radius=15, color='#3186CC', fill_color = '#3186CC', fill=True).add_to(map)
        
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
