# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
from tqdm import tqdm_notebook
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome('../../driver/chromedriver')
driver.get("http://franchise.ftc.go.kr/user/extra/main/70/firHope/listBrand/jsp/LayOutPage.do")

# %%
year_list_raw = driver.find_element_by_xpath("""//*[@id="selYear"]""")
year_list = year_list_raw.find_elements_by_tag_name("option")
year_names_values = [option.text for option in year_list]
year_names_values = year_names_values[:]
year_names_values
# Out:
# ['2017', '2016', '2015']

# %%
indus_list_raw = driver.find_element_by_xpath("""//*[@id="selIndus"]""")
indus_list = indus_list_raw.find_elements_by_tag_name("option")
indus_names_values = [option.text for option in indus_list]
indus_names_values = indus_names_values[1:]
indus_names_values
# Out:
# ['한식',
#  '분식',
#  '중식',
#  '일식',
#  '서양식',
#  '기타 외국식',
#  '패스트푸드',
#  '치킨',
#  '피자',
#  '제과제빵',
#  '아이스크림/빙수 ',
#  '커피',
#  '음료 (커피 외)',
#  '주점',
#  '기타 외식']

# %%
report_list_raw = driver.find_element_by_xpath("""//*[@id="selListType"]""")
report_list = report_list_raw.find_elements_by_tag_name("option")
report_names_values = [option.text for option in report_list]
report_names_values = report_names_values[:]
report_names_values
# Out:
# ['브랜드 개요', '가맹점 현황 정보', '가맹점 창업비용']

# %%
r = []
length = [6, 9, 10]
year = driver.find_element_by_id("selYear") #년도
year.send_keys(year_names_values[1])
    
for j in range(0,len(indus_names_values)):
    indus = driver.find_element_by_id("selIndus") #업종 중분류
    indus.send_keys(indus_names_values[j])
        
    for k in range(0,len(report_names_values)):
        report = driver.find_element_by_id("selListType") #비교항목
        report.send_keys(report_names_values[k])
        driver.find_element_by_xpath("""//*[@id="frmSearch"]/input[5]""").click()
            
        html=driver.page_source
        soup=BeautifulSoup(html,'html.parser')
            
        print(report_names_values[k])####

        rows = []        
        for row in range(int(len(soup.find_all('td'))/length[k])):
            row1 = []

            for i in range(0+(row*length[k]), length[k]+(row*length[k])) :
                tmp = soup.find_all('td')[i].get_text()
                tmp = tmp.replace('\n','')
                tmp = tmp.replace('\t','')
                tmp = tmp.replace('\xa0','')
                

                row1.append(tmp)
            rows.append(row1)
        r.append(rows)
    print(indus_names_values[j], 'done!')
# Out:
# 브랜드 개요
# 가맹점 현황 정보
# 가맹점 창업비용
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-2e2f02835bc2> in <module>()
#      25
#      26             for i in range(0+(row*6), 6+(row*6)) :
# ---> 27                 tmp = soup.find_all('td')[i].get_text()
#      28                 tmp = tmp.replace('\n','')
#      29                 tmp = tmp.replace('\t','')
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     546                           and (prefix is None or element.prefix == prefix)
#     547                 )
# --> 548                 return ResultSet(strainer, result)
#     549         results = ResultSet(strainer)
#     550         while True:
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __init__(self, source, result)
#    1800     that created it."""
#    1801     def __init__(self, source, result=()):
# -> 1802         super(ResultSet, self).__init__(result)
#    1803         self.source = source
#    1804
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in <genexpr>(.0)
#     541                 else:
#     542                     prefix = None
# --> 543                 result = (element for element in generator
#     544                           if isinstance(element, Tag)
#     545                             and element.name == name
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in descendants(self)
#    1329         while current is not stopNode:
#    1330             yield current
# -> 1331             current = current.next_element
#    1332
#    1333     # CSS selector code
#
# KeyboardInterrupt:

# %%
r[1]
# Out:
# [['평균', '-', '15.0', '3.0', '0.0', '1.0'],
#  ['0.0', '398,342(1.00)', '9,995(1.21)', '본죽', '본아이에프(주)', '1,178'],
#  ['34', '0', '46', '66', '201,456(0.51)', '16,923(0.04)'],
#  ['한솥', '(주)한솥', '673', '49', '12', '30'],
#  ['55', '296,124(0.74)', '21,901(0.05)', '고봉민김밥人', '케이비엠', '658'],
#  ['77', '0', '19', '82', '204,349(0.51)', '3,933(0.01)'],
#  ['놀부부대찌개', '(주)놀부', '480', '44', '71', '0'],
#  ['32', '0(0.00)', '0(0.00)', '큰맘할매순대국', '(주)보강엔터프라이즈', '349'],
#  ['87', '0', '12', '24', '324,486(0.81)', '12,848(0.03)'],
#  ['바다양푼이 동태탕 찜', '(주)예진희알이에프', '306', '112', '33', '0'],
#  ['0', '33,201(0.08)', '1,106(0.00)', '가장맛있는족발', '(주)가장맛있는족발', '302'],
#  ['87', '3', '2', '12', '732,982(1.84)', '21,768(0.05)'],
#  ['놀부보쌈', '(주)놀부', '267', '45', '56', '0'],
#  ['12', '0(0.00)', '0(0.00)', '채선당', '(주)채선당', '259'],
#  ['13', '28', '11', '24', '466,673(1.17)', '6,587(0.02)'],
#  ['본도시락', '본아이에프(주)', '257', '66', '0', '8'],
#  ['21', '325,775(0.82)', '25,664(0.06)', '신마포갈매기', '(주)디딤', '248'],
#  ['8', '0', '68', '22', '382,031(0.96)', '11,571(0.03)'],
#  ['원할머니', '원앤원(주)', '246', '19', '16', '1'],
#  ['13', '512,254(1.29)', '15,533(0.04)', '조마루감자탕', '(주)조마루', '199'],
#  ['8', '11', '0', '8', '452,913(1.14)', '8,181(0.02)'],
#  ['하남돼지집', '(주)하남에프앤비', '187', '44', '2', '5'],
#  ['10', '764,540(1.92)', '18,724(0.05)', '본죽&비빔밥 Cafe', '본아이에프(주)', '181'],
#  ['51', '0', '11', '7', '314,589(0.79)', '15,141(0.04)'],
#  ['엉터리생고기 두번째이야기 무한삼겹', '(주)영마루', '175', '177', '0', '2'],
#  ['6', '728,661(1.83)', '13,326(0.03)', '무봉리토종순대국', '무봉리토종순대국체인본부', '169'],
#  ['12', '18', '0', '6', '0(0.00)', '0(0.00)'],
#  ['새마을식당', '(주)더본코리아', '167', '17', '0', '22'],
#  ['6', '658,682(1.65)', '14,014(0.04)', '현대옥', '현대옥프랜차이즈', '166'],
#  ['11', '0', '8', '8', '452,009(1.13)', '11,428(0.03)'],
#  ['떡보의하루', '(주)떡파는사람들', '153', '0', '0', '5'],
#  ['2', '175,010(0.44)', '13,066(0.03)', '장충동왕족발보쌈', '(주)장충동왕족발', '153'],
#  ['1', '8', '0', '12', '114,154(0.29)', '6,014(0.02)'],
#  ['신의주찹쌀순대', '(주)거성푸드', '146', '43', '0', '9'],
#  ['16', '400,562(1.01)', '12,974(0.03)', '유가네닭갈비', '(주)바이올푸드글로벌', '141'],
#  ['34', '1', '10', '10', '408,784(1.03)', '9,618(0.02)'],
#  ['맛깔참죽', '(주)맛깔', '140', '19', '12', '0'],
#  ['9', '118,237(0.30)', '10,886(0.03)', '대구반야월막창', '(주)대구반야월막창', '140'],
#  ['20', '12', '18', '5', '162,026(0.41)', '6,451(0.02)'],
#  ['화통삼', '(주)행복한상상에프앤비', '136', '9', '0', '55'],
#  ['15', '461,720(1.16)', '11,067(0.03)', '박가부대', '원앤원(주)', '134'],
#  ['27', '14', '0', '10', '251,741(0.63)', '8,372(0.02)'],
#  ['오봉도시락', '(주)오색만찬', '129', '31', '0', '32'],
#  ['11', '94,503(0.24)', '9,290(0.02)', '미스터보쌈5379', '(주)푸디아', '121'],
#  ['42', '0', '7', '11', '238,774(0.60)', '17,400(0.04)'],
#  ['이화수전통육개장', '이화수', '117', '52', '0', '0'],
#  ['1', '674,829(1.69)', '13,908(0.03)', '엉터리생고기', '(주)영마루', '106'],
#  ['26', '0', '16', '3', '714,822(1.79)', '13,462(0.03)'],
#  ['이바돔감자탕', '(주)이바돔', '105', '0', '15', '0'],
#  ['3', '807,662(2.03)', '7,180(0.02)', '짚신매운갈비찜', '(주)음식생각', '104'],
#  ['9', '0', '12', '16', '469,264(1.18)', '18,025(0.05)'],
#  ['킹콩부대찌개', '(주)에스엘에프앤비', '101', '29', '0', '9'],
#  ['8', '320,245(0.80)', '9,907(0.02)', '육쌈냉면', '(주)육쌈', '100'],
#  ['11', '0', '2', '8', '406,731(1.02)', '14,100(0.04)'],
#  ['인생극장', '(주)에이치티코리아', '94', '53', '0', '14'],
#  ['0', '158,036(0.40)', '5,267(0.01)', '통뼈감자탕', '(주)명가', '94'],
#  ['22', '0', '7', '4', '243,545(0.61)', '4,388(0.01)'],
#  ['한신포차', '(주)더본코리아', '94', '17', '0', '1'],
#  ['4', '968,553(2.43)', '14,243(0.04)', '도야족발', '(주)도야푸드', '90'],
#  ['44', '0', '4', '0', '0(0.00)', '0(0.00)'],
#  ['빚은', '(주)에스피씨삼립', '89', '2', '0', '6'],
#  ['2', '194,900(0.49)', '13,844(0.03)', '참이맛감자탕', '(주)참이맛', '89'],
#  ['14', '0', '3', '0', '422,238(1.06)', '8,107(0.02)'],
#  ['명동칼국수샤브샤브', '(주)명동', '87', '6', '0', '7'],
#  ['9', '386,236(0.97)', '9,150(0.02)', '송담추어탕', '(주)송담', '83'],
#  ['14', '0', '15', '2', '349,940(0.88)', '6,744(0.02)'],
#  ['시루향기', '(주)향기나는사람들', '82', '7', '0', '7'],
#  ['9', '318,452(0.80)', '8,876(0.02)', '원조전통명가 통큰할매순대국', '(주)세븐하베스트', '81'],
#  ['51', '2', '6', '2', '214,394(0.54)', '7,816(0.02)'],
#  ['꽃마름', '(주)예울에프씨', '81', '18', '0', '33'],
#  ['8', '845,297(2.12)', '28,730(0.07)', '담소사골순대', '(주)담소이야기', '80'],
#  ['26', '0', '3', '5', '562,768(1.41)', '16,019(0.04)'],
#  ['맛찬들왕소금구이', '(주)맛찬들', '78', '19', '5', '0'],
#  ['5', '1,418,874(3.56)', '19,133(0.05)', '한방전주콩나물국밥', '(주)한사랑푸드', '77'],
#  ['11', '0', '7', '2', '399,518(1.00)', '12,594(0.03)'],
#  ['방일해장국', '(주)방일에프씨', '75', '3', '0', '4'],
#  ['1', '231,900(0.58)', '5,824(0.01)', '진배기 원조할매국밥', '진배기', '74'],
#  ['3', '2', '0', '0', '326,233(0.82)', '8,672(0.02)'],
#  ['콩불', '(주)8푸드', '73', '0', '0', '1'],
#  ['7', '200,586(0.50)', '6,686(0.02)', '맛나감자탕', '리브가푸드시스템(주)', '73'],
#  ['7', '1', '0', '1', '540,390(1.36)', '6,462(0.02)'],
#  ['손큰할매순대국', '(주)손큰', '72', '13', '30', '0'],
#  ['7', '305,178(0.77)', '10,985(0.03)', '돈통마늘보쌈', '(주)코리아푸딩', '71'],
#  ['7', '5', '12', '7', '330,159(0.83)', '8,976(0.02)'],
#  ['일미리금계찜닭', '(주)일미리', '71', '26', '0', '12'],
#  ['0', '195,102(0.49)', '10,573(0.03)', '홍익궁중전통육개장', '(주)홍익푸드', '70'],
#  ['32', '0', '4', '3', '517,746(1.30)', '11,720(0.03)'],
#  ['백채', '(주)심플맨', '69', '54', '0', '0'],
#  ['2', '274,530(0.69)', '22,053(0.06)', '진이찬방', '진이푸드(주)', '69'],
#  ['27', '5', '4', '3', '157,808(0.40)', '11,595(0.03)'],
#  ['육회지존', '인터푸드플래닝', '68', '0', '0', '0'],
#  ['0', '321,923(0.81)', '10,835(0.03)', '삼겹파티', '(주)엠지에이치', '67'],
#  ['7', '0', '8', '7', '210,830(0.53)', '5,017(0.01)'],
#  ['쌈촌', '(주)쌈촌패밀리', '66', '4', '0', '18'],
#  ['8', '319,874(0.80)', '4,764(0.01)', '남다른감자탕(男다른감子탕)', '(주)보하라', '66'],
#  ['15', '1', '0', '5', '704,941(1.77)', '10,236(0.03)'],
#  ['병천황토방순대', '(주)병천아우내식품', '65', '1', '0', '8'],
#  ['0', '17,670(0.04)', '560(0.00)', '송주불냉면앤칼국수', '브이케이피(주)', '64'],
#  ['8', '0', '10', '0', '46,740(0.12)', '2,361(0.01)'],
#  ['디코레북창동순두부', '(주)제이비에스디', '62', '3', '5', '9'],
#  ['6', '522,386(1.31)', '13,653(0.03)', '돌배기집', '(주)더본코리아', '61'],
#  ['28', '0', '0', '0', '1,100,148(2.76)', '18,646(0.05)'],
#  ['원조의령소바', '(주)의령소바', '61', '9', '0', '11'],
#  ['8', '0(0.00)', '0(0.00)', '지호한방삼계탕', '(주)지호', '61'],
#  ['3', '0', '2', '7', '381,090(0.96)', '7,980(0.02)'],
#  ['등뼈가', '(주)푸드원', '61', '5', '0', '4'],
#  ['3', '252,453(0.63)', '4,930(0.01)', '구이가', '(주)가업에프씨', '60'],
#  ['5', '0', '21', '2', '436,342(1.10)', '10,629(0.03)'],
#  ['서래갈매기', '(주)서래스터', '60', '10', '17', '0'],
#  ['0', '409,679(1.03)', '12,062(0.03)', '한촌설렁탕', '(주)이연에프엔씨', '60'],
#  ['5', '3', '0', '7', '536,440(1.35)', '11,394(0.03)'],
#  ['5.5닭갈비', '(주)오점오', '58', '5', '0', '6'],
#  ['4', '0(0.00)', '0(0.00)', '돈가네김치찌개', '(주)에프앤씨돈가네', '58'],
#  ['5', '2', '0', '4', '261,150(0.66)', '6,584(0.02)'],
#  ['누리마을감자탕', '(주)영일유통', '57', '7', '0', '5'],
#  ['3', '374,433(0.94)', '4,048(0.01)', '본래순대', '(주)도드람에프씨 가맹사업본부', '56'],
#  ['43', '0', '1', '0', '152,048(0.38)', '4,548(0.01)'],
#  ['교동전선생', '(주)교동', '56', '0', '9', '0'],
#  ['1', '277,322(0.70)', '9,244(0.02)', '청진동해장국', '(주)씨제이디푸드시스템', '56'],
#  ['3', '5', '0', '1', '0(0.00)', '0(0.00)'],
#  ['생선지존진땡이', '(주)모메존', '54', '15', '0', '15'],
#  ['0', '312,461(0.78)', '6,989(0.02)', '김명자낙지마당', '(주)김명자', '53'],
#  ['4', '0', '13', '0', '404,684(1.02)', '9,107(0.02)'],
#  ['한가네숯불닭갈비', '(주)한경코퍼레이션', '53', '12', '0', '6'],
#  ['6', '398,958(1.00)', '12,428(0.03)', '더 맛(the 맛)', '(주)더맛푸드', '52'],
#  ['5', '0', '13', '1', '252,638(0.63)', '11,073(0.03)'],
#  ['정석통바베큐족구이', '(주)케이제이푸드시스템', '51', '5', '0', '5'],
#  ['1', '69,243(0.17)', '2,614(0.01)', '홍춘천', '(주)훌랄라', '51'],
#  ['46', '0', '0', '0', '121,339(0.30)', '3,372(0.01)'],
#  ['미쓰족발', '보승FC', '50', '19', '3', '0'],
#  ['0', '472,520(1.19)', '13,180(0.03)', '굴마을낙지촌', '(주)두둑한행복', '49'],
#  ['4', '0', '10', '1', '306,854(0.77)', '8,810(0.02)'],
#  ['우가양평해장국', '(유)전라도푸드에프앤씨', '49', '8', '4', '0'],
#  ['7', '258,301(0.65)', '4,558(0.01)', '청진동해장국', '(주)에이치에스푸드 ', '49'],
#  ['3', '0', '4', '1', '170,637(0.43)', '6,352(0.02)'],
#  ['본가', '(주)더본코리아', '48', '5', '0', '4'],
#  ['0', '1,163,124(2.92)', '8,249(0.02)', '내담 대구탕 해물갈비찜 ', '(주)씨에스에프씨', '47'],
#  ['19', '0', '2', '3', '0(0.00)', '0(0.00)'],
#  ['완산골명가', '(주)더드림에프에스', '47', '6', '0', '15'],
#  ['1', '0(0.00)', '0(0.00)', 'THE진국', '(주)섬김과나눔', '47'],
#  ['15', '0', '2', '5', '503,677(1.26)', '15,994(0.04)'],
#  ['쌀눈쌀 현미누룽지', '(주)엄마', '46', '46', '0', '0'],
#  ['0', '59,948(0.15)', '25,008(0.06)', '별법 동태탕 왕해물찜 ', '(주)씨에스에프씨', '46'],
#  ['2', '2', '0', '0', '0(0.00)', '0(0.00)'],
#  ['안동국밥', '(주)빛솜푸드', '45', '19', '8', '2'],
#  ['2', '382,300(0.96)', '9,328(0.02)', '어머나생고기', '(주)스타프렌차이즈', '45'],
#  ['51', '0', '6', '2', '458,157(1.15)', '9,426(0.02)'],
#  ['얌샘김밥', '(주)얌샘', '45', '37', '0', '0'],
#  ['0', '298,818(0.75)', '19,682(0.05)', '국사랑', '케이씨컴퍼니', '44'],
#  ['18', '0', '14', '0', '154,887(0.39)', '14,185(0.04)'],
#  ['착한낙지', '푸드이노베이션', '44', '7', '0', '8'],
#  ['0', '0(0.00)', '0(0.00)', '천하제일왕족발', '(주)훌랄라', '43'],
#  ['9', '9', '0', '0', '68,186(0.17)', '3,076(0.01)'],
#  ['삼겹싸롱', '(주)행복한상상에프앤비', '43', '43', '0', '0'],
#  ['2', '917,649(2.30)', '20,775(0.05)', '신선설농탕', '(주)쿠드', '43'],
#  ['2', '0', '0', '1', '1,965,611(4.93)', '34,091(0.09)'],
#  ['육풍', '(주)보담', '43', '18', '4', '10'],
#  ['0', '851,095(2.14)', '12,402(0.03)', '청와삼대', '(주)봄봄', '42'],
#  ['16', '1', '2', '1', '645,880(1.62)', '12,168(0.03)'],
#  ['내가찜한닭', '(주)마이푸드', '41', '13', '0', '5'],
#  ['0', '606,011(1.52)', '15,467(0.04)', '백종원의원조쌈밥집', '(주)더본코리아', '40'],
#  ['11', '0', '3', '1', '564,203(1.42)', '8,060(0.02)'],
#  ['진성아구찜', '진성', '40', '3', '0', '4'],
#  ['2', '232,760(0.58)', '6,147(0.02)', '곤지암할매소머리국밥', '(주)동의보감농수산', '40'],
#  ['30', '0', '14', '0', '143,959(0.36)', '4,570(0.01)'],
#  ['돈도니석쇠한판불고기', '디오(DO)푸드시스템', '40', '14', '0', '4'],
#  ['5', '171,648(0.43)', '9,860(0.02)', '청양일초 ', '청해유통', '38'],
#  ['5', '0', '9', '2', '265,859(0.67)', '4,343(0.01)'],
#  ['신촌설렁탕', '(주)신촌푸드', '38', '8', '5', '0'],
#  ['0', '380,914(0.96)', '9,767(0.02)', '용추골미궁순대', '칠연푸드시스템', '38'],
#  ['2', '0', '7', '3', '211,991(0.53)', '6,724(0.02)'],
#  ['또와유 명태간장조림', '(주)해오름에프에스', '38', '8', '0', '4'],
#  ['3', '357,773(0.90)', '10,590(0.03)', '전주남문조춘자토종피순대국', '(주)비엔에스푸드', '37'],
#  ['17', '0', '6', '0', '142,076(0.36)', '4,230(0.01)'],
#  ['안동본가국밥', '(주)두웰푸드', '37', '22', '0', '0'],
#  ['3', '0(0.00)', '0(0.00)', '존슨부대찌개', '(주)존슨푸드코리아', '36'],
#  ['10', '0', '0', '0', '259,639(0.65)', '9,242(0.02)'],
#  ['맵꼬만명태', '해달에프앤씨', '36', '2', '7', '0'],
#  ['3', '206,617(0.52)', '7,256(0.02)', '군산오징어', '(주)산무리', '36'],
#  ['13', '2', '3', '0', '427,328(1.07)', '13,047(0.03)'],
#  ['손문대구막창갈매기살', '(주)손문에프앤씨', '36', '5', '1', '8'],
#  ['2', '49,024(0.12)', '1,898(0.00)', '계경순대국', '지강에프앤비(주)', '36'],
#  ['2', '0', '3', '0', '301,062(0.76)', '12,123(0.03)'],
#  ['돌깨마을맷돌순두부', '(주)자연가득', '35', '3', '0', '6'],
#  ['0', '457,301(1.15)', '16,768(0.04)', '부산아지매국밥', '(주)제이엘푸드', '34'],
#  ['7', '0', '4', '5', '527,986(1.33)', '20,024(0.05)'],
#  ['삼백집', '(주)휴림', '33', '10', '0', '5'],
#  ['2', '38,506(0.10)', '878(0.00)', '1인자감자탕', '(주)제이에스일인자', '32'],
#  ['5', '0', '10', '1', '428,536(1.08)', '10,218(0.03)'],
#  ['밥장인돼지찌개', '(주)밥장인', '32', '6', '0', '4'],
#  ['6', '0(0.00)', '0(0.00)', '화포식당', '(주)다이닝에스엠', '32'],
#  ['17', '0', '3', '6', '87,060(0.22)', '2,033(0.01)'],
#  ['떡담', '라이스파이', '32', '6', '0', '7'],
#  ['0', '83,573(0.21)', '3,509(0.01)', '육봉달', '(주)티아이코스모스', '32'],
#  ['3', '0', '6', '4', '578,855(1.45)', '9,153(0.02)'],
#  ['궁채', '(주)이밥스', '32', '5', '0', '7'],
#  ['7', '293,115(0.74)', '1,331(0.00)', '착한돼지', '(주)착한푸드', '32'],
#  ['3', '0', '6', '1', '886,383(2.23)', '10,087(0.03)'],
#  ['돈데이', '(주)썬미트', '32', '17', '4', '0'],
#  ['0', '349,742(0.88)', '7,777(0.02)', '오늘한점', '(주)우용에프앤비 ', '31'],
#  ['5', '8', '0', '0', '494,019(1.24)', '10,724(0.03)'],
#  ['착한고기', '(주)착한고기', '31', '1', '0', '16'],
#  ['1', '594,346(1.49)', '5,943(0.01)', '소공동뚝배기집', '(주)오백미라클', '30'],
#  ['7', '0', '3', '2', '396,380(1.00)', '13,558(0.03)'],
#  ['팔색삼겹살', '(주)8푸드', '30', '1', '0', '3'],
#  ['1', '365,057(0.92)', '12,169(0.03)', '목촌사골돼지국밥', '(주)행운식품', '30'],
#  ['6', '9', '0', '2', '538,381(1.35)', '9,601(0.02)'],
#  ['대독장', '(주)제니스에프앤비', '30', '12', '0', '2'],
#  ['0', '326,766(0.82)', '9,355(0.02)', '망향비빔국수', '블루밀', '29'],
#  ['3', '0', '4', '4', '421,158(1.06)', '7,275(0.02)'],
#  ['정가대박집', '(주)정웅', '29', '5', '0', '1'],
#  ['0', '589,484(1.48)', '6,410(0.02)', '백철판0410', '(주)더본코리아', '29'],
#  ['17', '0', '3', '1', '497,231(1.25)', '11,049(0.03)'],
#  ['정성신더큰도시락', '(주)더큰', '29', '21', '7', '0'],
#  ['4', '0(0.00)', '0(0.00)', '홍스쭈꾸미', '(주)리더스코리아코퍼레이션', '29'],
#  ['5', '0', '4', '1', '0(0.00)', '0(0.00)'],
#  ['뚱뚱이할머니족발보쌈', '(주)제이비에프씨', '28', '0', '0', '8'],
#  ['0', '294,221(0.74)', '17,177(0.04)', '곽만근갈비탕', '(주)곽푸드에프씨', '28'],
#  ['0', '0', '1', '3', '864,351(2.17)', '15,250(0.04)'],
#  ['예향정', 'DK nine 푸드', '28', '24', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '화평동왕냉면', '해피브릿지협동조합', '28'],
#  ['4', '10', '0', '0', '404,687(1.02)', '22,073(0.06)'],
#  ['노마세야매운갈비찜', '(주)노마세야컴퍼니', '28', '10', '0', '3'],
#  ['10', '307,208(0.77)', '10,678(0.03)', '샤브쌈주머니', '위드몬', '28'],
#  ['7', '0', '0', '2', '556,732(1.40)', '7,720(0.02)'],
#  ['만족오향족발', '(주)만점족', '28', '13', '0', '1'],
#  ['2', '697,027(1.75)', '21,996(0.06)', '화덕구이족보통', '(주)다온에프비', '27'],
#  ['21', '0', '6', '0', '115,045(0.29)', '6,527(0.02)'],
#  ['달인의찜닭', '달인의찜닭', '27', '4', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '월수금', '월수금', '27'],
#  ['8', '0', '2', '2', '248,644(0.62)', '5,737(0.01)'],
#  ['대관령양푼이동태찌개', '대관령양푼이동태찌개', '27', '1', '0', '5'],
#  ['0', '0(0.00)', '0(0.00)', '주원명가', '(주)주원산오리', '26'],
#  ['1', '0', '1', '0', '88,290(0.22)', '1,981(0.00)'],
#  ['콩두', '(주)가효', '26', '6', '3', '0'],
#  ['3', '241,846(0.61)', '12,479(0.03)', '호세야오리바베큐', '호세야(주)', '26'],
#  ['13', '0', '3', '0', '49,237(0.12)', '4,389(0.01)'],
#  ['오징어와친구들', '(주)미래원에프앤씨', '26', '9', '6', '0'],
#  ['0', '110,000(0.28)', '4,213(0.01)', '접시꽃보쌈', '(주)프로스탭컨설팅', '26'],
#  ['4', '13', '0', '0', '528,803(1.33)', '10,380(0.03)'],
#  ['보리네생고깃간', '(주)다담', '26', '0', '0', '6'],
#  ['0', '581,863(1.46)', '9,535(0.02)', '바보형제쭈꾸미', '(주)바보형제스토리', '26'],
#  ['1', '13', '2', '7', '180,274(0.45)', '2,397(0.01)'],
#  ['놀부화덕족발', '(주)놀부', '26', '2', '23', '0'],
#  ['20', '122,814(0.31)', '4,323(0.01)', '꼬꼬씨참숯불닭갈비', '(주)꼬꼬씨에프', '25'],
#  ['23', '0', '2', '3', '93,980(0.24)', '3,851(0.01)'],
#  ['시골통돼지볶음', '코아FS', '25', '4', '0', '0'],
#  ['4', '182,389(0.46)', '6,909(0.02)', '금강산감자탕', '농업회사법인 구삐(주)', '25'],
#  ['4', '0', '5', '2', '278,091(0.70)', '15,044(0.04)'],
#  ['족장', '(주)족장에프앤비', '25', '4', '0', '6'],
#  ['0', '312,658(0.78)', '12,914(0.03)', '맛내음왕소금구이', '(주)인큐베이팅홀딩스', '25'],
#  ['7', '0', '0', '0', '586,941(1.47)', '13,477(0.03)'],
#  ['1988고기불패', '1988고기불패', '25', '27', '0', '2'],
#  ['0', '0(0.00)', '0(0.00)', '전주팔미콩나물국밥', '전주팔미', '25'],
#  ['25', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['이바돔 외식 Family', '(주)이바돔', '25', '20', '2', '0'],
#  ['0', '1,141,951(2.87)', '7,536(0.02)', '조방낙지', '(주)디에이치푸드', '25'],
#  ['0', '0', '0', '1', '0(0.00)', '0(0.00)'],
#  ['닭갈비제작소', '(주)닥인흥업', '24', '14', '0', '0'],
#  ['0', '459,985(1.15)', '7,638(0.02)', '장패 (JANGPAE)', '장패체인사업본부', '24'],
#  ['6', '2', '1', '2', '344,442(0.86)', '8,861(0.02)'],
#  [' 뿔발', '농업회사법인 (주)을과 함께', '24', '24', '0', '0'],
#  ['0', '143,789(0.36)', '13,651(0.03)', '마왕족발', '(주)콜라겐랩', '24'],
#  ['24', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['설동궁찜닭', '설동궁', '24', '17', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '삼시세때', '(주)국보푸드시스템', '24'],
#  ['0', '2', '1', '4', '272,640(0.68)', '8,860(0.02)'],
#  ['아빠곰탕', '(주)프레솔', '24', '25', '0', '2'],
#  ['0', '309,626(0.78)', '14,622(0.04)', '쭈꾸미블루스', '(주)펀투비위드', '24'],
#  ['31', '0', '23', '0', '164,803(0.41)', '5,649(0.01)'],
#  ['미스터오징어', '미스앤미스터㈜', '24', '12', '0', '1'],
#  ['1', '780,750(1.96)', '20,302(0.05)', '마당쇠돼지갈비', '(주)마당쇠', '23'],
#  ['23', '0', '0', '0', '258,873(0.65)', '9,132(0.02)'],
#  ['유장춘닭개장', '(주)제이씨씨푸드', '23', '6', '0', '3'],
#  ['2', '380,655(0.96)', '7,112(0.02)', '쉐프삼촌', '쉐프삼촌', '23'],
#  ['23', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['단물곤물', '단물곤물', '23', '8', '2', '0'],
#  ['1', '227,394(0.57)', '8,679(0.02)', '주구장창석쇠불판', '다드림푸드', '23'],
#  ['8', '1', '1', '5', '213,838(0.54)', '13,796(0.03)'],
#  ['막창도둑', '(주)엠디푸드시스템', '23', '14', '0', '0'],
#  ['0', '262,880(0.66)', '7,766(0.02)', '동서네낙지', '동서네낙지', '23'],
#  ['7', '2', '0', '1', '235,668(0.59)', '5,592(0.01)'],
#  ['두리맛감자탕', '(주)두리맛푸드', '23', '5', '0', '4'],
#  ['0', '373,105(0.94)', '7,750(0.02)', '나능이능이버섯백숙', '(주)해우앤릴리스', '23'],
#  ['4', '0', '0', '1', '319,251(0.80)', '6,606(0.02)'],
#  ['두찜', '(주)기영에프앤비', '22', '22', '0', '0'],
#  ['0', '202,805(0.51)', '8,090(0.02)', '구팔한우', '(주)트루팜', '22'],
#  ['19', '0', '1', '0', '499,726(1.25)', '12,965(0.03)'],
#  ['어바웃샤브', '(주)올어바웃푸드', '22', '2', '3', '2'],
#  ['1', '276,119(0.69)', '4,859(0.01)', '달인박경규항아리보쌈', '항아리보쌈', '22'],
#  ['14', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['미다래', '미다래에프앤디(주)', '22', '0', '0', '4'],
#  ['1', '57,034(0.14)', '4,038(0.01)', '제주애한판', '(주)에스지프랜차이즈', '22'],
#  ['7', '0', '8', '0', '403,858(1.01)', '10,121(0.03)'],
#  ['남노갈비', '(주)조이에프앤비', '22', '6', '0', '3'],
#  ['0', '174,880(0.44)', '3,976(0.01)', '청국장과보리밥', '농협회사법인(주)인건', '21'],
#  ['2', '0', '0', '0', '465,445(1.17)', '9,195(0.02)'],
#  ['대박통', '대박통', '21', '5', '0', '3'],
#  ['1', '230,118(0.58)', '9,683(0.02)', '유가네 맑은곰탕', '(주)유가네', '21'],
#  ['15', '0', '4', '0', '91,833(0.23)', '10,823(0.03)'],
#  ['장모족발시크릿레시피', '(주)섬김에프씨', '21', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '토부리 병천순대', '(주)토부리', '21'],
#  ['4', '0', '5', '1', '176,988(0.44)', '5,237(0.01)'],
#  ['모박사부대찌개', '모박사본점', '21', '0', '0', '6'],
#  ['0', '0(0.00)', '0(0.00)', '온국민순대국', '(주)손정', '20'],
#  ['20', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['양평뚝배기해장국', '(주)뉴서진식품', '20', '2', '0', '2'],
#  ['2', '337,826(0.85)', '8,447(0.02)', '신진성아구찜', '(주)신진성에프앤비', '20'],
#  ['6', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['삼삼이네', '(주)오즈하우스', '20', '3', '0', '4'],
#  ['0', '242,444(0.61)', '12,411(0.03)', '송가네왕족발', '송가네식품(주)', '20'],
#  ['1', '0', '1', '0', '201,196(0.51)', '7,806(0.02)'],
#  ['화화', '(주)미소에프엔씨', '20', '4', '2', '4'],
#  ['4', '590,305(1.48)', '11,232(0.03)', '김해시락국밥', '토장원', '19'],
#  ['1', '0', '0', '1', '100,783(0.25)', '4,106(0.01)'],
#  ['춘부집목살스테끼와껍데기', '(주)더푸드상상', '19', '2', '5', '0'],
#  ['1', '281,999(0.71)', '9,994(0.03)', '미사리밀빛초계국수', '(주)밀빛', '19'],
#  ['4', '1', '4', '1', '417,429(1.05)', '494(0.00)'],
#  ['배부장찌개', '배부장찌개', '19', '19', '0', '0'],
#  ['1', '487,166(1.22)', '19,783(0.05)', '돈오락쪽갈비', '(주)지강푸드', '19'],
#  ['5', '1', '1', '0', '68,483(0.17)', '2,228(0.01)'],
#  ['집으로돼지', '(주)메이에프앤에스', '19', '13', '0', '0'],
#  ['2', '318,536(0.80)', '25,125(0.06)', '논골집', '정준유통', '19'],
#  ['1', '0', '1', '2', '482,768(1.21)', '11,972(0.03)'],
#  ['어죽이네철렵국', '어죽이네철렵국', '19', '2', '0', '1'],
#  ['0', '180,631(0.45)', '4,773(0.01)', '본설렁탕', '본아이에프(주)', '19'],
#  ['9', '0', '2', '0', '328,316(0.82)', '9,218(0.02)'],
#  ['화덕초대파불고기', '프랜차이즈새늘', '19', '19', '0', '3'],
#  ['0', '275,164(0.69)', '11,132(0.03)', '벌집한판무한리필', '(주)에이치엘인코퍼레이트', '19'],
#  ['23', '0', '4', '0', '463,762(1.16)', '7,374(0.02)'],
#  ['홍대칼국수와족발', '(주)다온에프엔비', '19', '6', '0', '1'],
#  ['3', '428,994(1.08)', '14,139(0.04)', '블랭', '지 에프 케이', '19'],
#  ['19', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['청진동해장국', '우인푸드시스템', '19', '3', '0', '4'],
#  ['1', '0(0.00)', '0(0.00)', '변사또', '유엔에프시', '18'],
#  ['1', '0', '4', '4', '0(0.00)', '0(0.00)'],
#  ['가인채샤브샤브&샐러드', '(주)가인채', '18', '1', '0', '3'],
#  ['1', '790,139(1.98)', '6,843(0.02)', '싱글벙글복어', '싱글벙글', '18'],
#  ['1', '2', '0', '0', '138,685(0.35)', '2,000(0.01)'],
#  ['수육국밥.보쌈전문점 더참맛수육국밥앤보쌈', '(주)더참맛푸드', '18', '1', '6', '0'],
#  ['3', '595,098(1.49)', '13,839(0.03)', '삼겹촌놈', '솔담', '18'],
#  ['6', '0', '0', '0', '409,825(1.03)', '9,996(0.03)'],
#  ['개미집', '(주)낙지볶음개미집', '18', '13', '1', '0'],
#  ['0', '330,880(0.83)', '7,795(0.02)', '한근에한근더', '진선푸드시스템', '18'],
#  ['4', '0', '4', '0', '477,665(1.20)', '8,161(0.02)'],
#  ['횡성생고기', '(주)허성준의 맛 이야기', '18', '5', '1', '3'],
#  ['0', '0(0.00)', '0(0.00)', '원조전통명가 통큰할매순대국', '(주)로드썬', '18'],
#  ['17', '0', '2', '0', '484,228(1.22)', '14,720(0.04)'],
#  ['병천아우내장터순대', '(주)아우내종합상사', '18', '0', '6', '0'],
#  ['0', '0(0.00)', '0(0.00)', '오복미역', '(주)오복푸드', '18'],
#  ['14', '0', '0', '0', '936,499(2.35)', '13,311(0.03)'],
#  ['콩시루', '시루유통', '18', '1', '0', '0'],
#  ['0', '733,059(1.84)', '24,677(0.06)', '조부자매운순대가', '조부자에프앤비', '18'],
#  ['2', '0', '1', '2', '241,618(0.61)', '7,725(0.02)'],
#  ['무한삼겹시대', '(주)한세푸드', '18', '27', '0', '9'],
#  ['0', '378,819(0.95)', '8,341(0.02)', '최숙이네', '(주)제이엠푸드코리아', '18'],
#  ['0', '5', '0', '0', '371,825(0.93)', '11,642(0.03)'],
#  ['용인토종순대국', '(주)케이엔푸드', '18', '0', '0', '2'],
#  ['0', '151,579(0.38)', '3,742(0.01)', '나이스투미츄', '아이에스 크리에이티브', '17'],
#  ['5', '5', '0', '1', '201,155(0.50)', '9,242(0.02)'],
#  ['하늘본닭', '하늘본닭에프앤비(주)', '17', '2', '0', '0'],
#  ['2', '423,617(1.06)', '9,549(0.02)', '갈비씨', '푸드테인먼트', '17'],
#  ['2', '0', '13', '0', '222,285(0.56)', '8,061(0.02)'],
#  ['불티매운족발', '(주)한아름푸드', '17', '0', '0', '8'],
#  ['0', '21,922(0.06)', '1,019(0.00)', '배달삼겹 돼지되지', '주식회사 정담에프앤비', '17'],
#  ['17', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['만나고쪽갈비가', '맛있는에프앤비(F&B)', '17', '8', '0', '3'],
#  ['0', '356,728(0.90)', '13,999(0.04)', '셰프의국수앤육개장', '(주)바인에프씨', '17'],
#  ['3', '0', '2', '1', '278,466(0.70)', '12,360(0.03)'],
#  ['본앤본', '본앤본(주)', '17', '8', '0', '1'],
#  ['1', '174,802(0.44)', '12,273(0.03)', '육미명가옛날아우내순대&보쌈', '(주)병천아우내식품', '17'],
#  ['12', '0', '3', '0', '363,467(0.91)', '9,006(0.02)'],
#  ['진서방곱이네', '제이앤비즈(J&Biz)', '17', '0', '0', '12'],
#  ['0', '193,208(0.49)', '9,328(0.02)', '마녀가 만든 족발', '제이에이치푸드(주)', '17'],
#  ['17', '0', '0', '1', '356,572(0.90)', '11,482(0.03)'],
#  ['유성닭발', '와이(Y) 플래닛 프로젝트', '16', '11', '0', '2'],
#  ['1', '0(0.00)', '0(0.00)', '조가네갑오징어', '(주)조앤이푸드', '16'],
#  ['4', '0', '3', '0', '1,329,796(3.34)', '27,138(0.07)'],
#  ['신의주부대찌개', '미트준', '16', '0', '0', '0'],
#  ['0', '287,200(0.72)', '34,759(0.09)', '평안도찹쌀순대전문점', '(주)평원', '16'],
#  ['1', '2', '8', '1', '301,696(0.76)', '9,212(0.02)'],
#  ['와촌식육식당', '(주)와촌본가', '16', '11', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '사랑담은묵은지찜찌개', '(주)사랑담은', '16'],
#  ['1', '0', '0', '2', '172,299(0.43)', '6,125(0.02)'],
#  ['백정', '(주)육칠팔', '16', '1', '13', '0'],
#  ['0', '841,069(2.11)', '19,669(0.05)', '한패', '(주)보성녹돈', '16'],
#  ['16', '0', '0', '0', '510,486(1.28)', '7,165(0.02)'],
#  ['옛날농장', '(주)첨성대', '15', '1', '0', '1'],
#  ['7', '789,309(1.98)', '15,218(0.04)', '콩뿌리 전주콩나물국밥', '콩뿌리 프랜차이즈', '15'],
#  ['15', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['통큰낙지', '골든코리아', '15', '1', '1', '3'],
#  ['0', '396,594(1.00)', '7,306(0.02)', '뚱삼이와대삼이', '(주)엠지에이치', '15'],
#  ['10', '0', '0', '4', '255,125(0.64)', '6,074(0.02)'],
#  ['주왕산삼계탕', '(주)대가야', '15', '4', '0', '1'],
#  ['2', '238,005(0.60)', '3,757(0.01)', '오술차', '(주)오술차', '15'],
#  ['14', '0', '0', '0', '184,030(0.46)', '12,607(0.03)'],
#  ['싸움의고수', '(주)란체스터에프앤비', '15', '13', '0', '0'],
#  ['0', '520,797(1.31)', '32,305(0.08)', '발빠닭', '(주)어나더푸드컬쳐', '15'],
#  ['7', '1', '1', '0', '373,708(0.94)', '11,301(0.03)'],
#  ['마시찜(MASIZZIM)', '(주)오감만족', '15', '6', '0', '2'],
#  ['2', '417,557(1.05)', '12,855(0.03)', '오모리찌개', '(주)오모리', '15'],
#  ['0', '1', '0', '0', '643,045(1.61)', '14,666(0.04)'],
#  ['두남자찜닭', '(주)두남자컴퍼니', '14', '2', '0', '2'],
#  ['0', '594,137(1.49)', '9,593(0.02)', '채상궁', '(주)보성녹돈', '14'],
#  ['1', '0', '4', '1', '504,163(1.27)', '5,749(0.01)'],
#  ['무한리필929숯불닭갈비', '(주)웰푸드컴퍼니', '14', '14', '0', '0'],
#  ['1', '585,925(1.47)', '14,062(0.04)', '대한닭발1979', '(주)씨에이치월드푸드', '14'],
#  ['4', '3', '0', '0', '219,052(0.55)', '10,207(0.03)'],
#  ['박군자진주냉면', '(주)진주교방', '14', '2', '0', '1'],
#  ['0', '0(0.00)', '0(0.00)', '풍남옥', '풍남옥프랜차이즈', '14'],
#  ['0', '0', '0', '0', '423,394(1.06)', '8,386(0.02)'],
#  ['큰정할매순대국', '(주)휴앤지', '14', '6', '0', '0'],
#  ['0', '370,904(0.93)', '13,153(0.03)', '백청우칼국수', '백청우칼국수', '14'],
#  ['2', '2', '0', '0', '327,932(0.82)', '7,477(0.02)'],
#  ['태성추어탕', '태성추어탕', '14', '2', '0', '1'],
#  ['0', '0(0.00)', '0(0.00)', '소래버섯나라', '(주)소래버섯', '14'],
#  ['1', '0', '3', '0', '287,334(0.72)', '4,459(0.01)'],
#  ['주순희찌개마을시골촌', '(주)순희에프앤비', '14', '3', '0', '4'],
#  ['0', '270,552(0.68)', '8,125(0.02)', '황홀한막창', '디오디시스템', '14'],
#  ['7', '1', '1', '1', '71,082(0.18)', '3,784(0.01)'],
#  ['봉평 메밀마당', '(주)동주물산', '14', '14', '0', '0'],
#  ['0', '55,100(0.14)', '2,074(0.01)', '하수련주왕산삼계탕', '주왕산삼계탕부산경남본부', '14'],
#  ['1', '6', '0', '0', '301,818(0.76)', '6,634(0.02)'],
#  ['삼육오족발찜닭', '(주)자연가득', '14', '5', '0', '3'],
#  ['4', '540,869(1.36)', '10,258(0.03)', '소담촌', '(주)웰빙코리아', '14'],
#  ['6', '1', '0', '0', '602,175(1.51)', '22,229(0.06)'],
#  ['정성본', '(주)정성본', '13', '0', '0', '4'],
#  ['5', '0(0.00)', '0(0.00)', '신정골', '(주)신정푸드', '13'],
#  ['0', '4', '1', '0', '150,595(0.38)', '3,638(0.01)'],
#  ['홍수계찜닭', '(주)마루퍼슨스', '13', '9', '0', '0'],
#  ['0', '429,109(1.08)', '11,891(0.03)', '단지막창', '단지푸드시스템', '13'],
#  ['0', '4', '0', '0', '306,317(0.77)', '7,657(0.02)'],
#  ['이종구낙지세상', '이종구낙지세상', '13', '7', '0', '0'],
#  ['0', '440,459(1.11)', '11,254(0.03)', '귀품찬', '(주)곽푸드에프씨', '13'],
#  ['3', '0', '2', '1', '1,099,038(2.76)', '9,461(0.02)'],
#  ['흑돼지 삼백식당', '정상FC', '13', '13', '0', '0'],
#  ['0', '557,803(1.40)', '9,976(0.03)', '양철북', '(주)마시명가', '13'],
#  ['4', '0', '1', '0', '269,510(0.68)', '8,444(0.02)'],
#  ['춘천꼬꼬닭갈비', '(주)중앙식품', '13', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '국민전통갈비', '(주)영원외식산업', '13'],
#  ['5', '0', '11', '0', '259,543(0.65)', '7,147(0.02)'],
#  ['소야돈', '(주)소야돈', '12', '3', '2', '0'],
#  ['0', '633,657(1.59)', '9,268(0.02)', '정통춘천닭갈비', '(주)정통푸드', '12'],
#  ['0', '4', '0', '0', '127,583(0.32)', '4,554(0.01)'],
#  ['소앤소', '도감푸드', '12', '3', '0', '0'],
#  ['0', '370,054(0.93)', '6,214(0.02)', '햇잎갈비', '햇잎푸드', '12'],
#  ['4', '0', '5', '0', '340,985(0.86)', '7,197(0.02)'],
#  ['추담골남원추어탕', '추사랑식품', '12', '2', '2', '0'],
#  ['0', '205,526(0.52)', '7,006(0.02)', '제주몬트락', '(주)모닥홀딩스', '12'],
#  ['10', '0', '0', '0', '964,540(2.42)', '13,608(0.03)'],
#  ['첫번째필족사랑', '거성푸드(주)', '12', '2', '0', '6'],
#  ['1', '146,206(0.37)', '6,873(0.02)', '천사곱창', '(주)식스텐비즈', '12'],
#  ['12', '0', '0', '0', '337,074(0.85)', '18,984(0.05)'],
#  ['번지농장돌판아구찜', '화산상사영농조합법인', '12', '2', '0', '1'],
#  ['2', '534,901(1.34)', '6,620(0.02)', '박수근네 온천골', '온천골푸드', '12'],
#  ['0', '2', '0', '1', '423,053(1.06)', '7,333(0.02)'],
#  ['오래오래장충동왕족발보쌈', '(주)미도식품', '12', '2', '1', '4'],
#  ['1', '35,541(0.09)', '2,356(0.01)', '하영멘도롱', '서울신문스포츠서울에이앤비(주)', '12'],
#  ['8', '0', '1', '0', '392,427(0.99)', '7,675(0.02)'],
#  ['대한상회신종수인', '대한상회F&B', '12', '0', '3', '0'],
#  ['0', '804,349(2.02)', '11,956(0.03)', '보리밥보쌈전문점보릿골', '(주)보릿골', '12'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['불로군불족발', '(주)불로군', '12', '1', '0', '25'],
#  ['5', '0(0.00)', '0(0.00)', '월홍갈비', '제이원푸드(주)', '12'],
#  ['2', '1', '1', '0', '291,604(0.73)', '7,538(0.02)'],
#  ['국민수육국밥&막국수 ', '(주)썬푸드', '12', '3', '0', '3'],
#  ['0', '55,618(0.14)', '1,694(0.00)', '삼겹랜드', '영진인터네셔널주식회사', '11'],
#  ['13', '0', '2', '0', '180,925(0.45)', '3,036(0.01)'],
#  ['욕쟁이할매순대국', '경안푸드', '11', '3', '2', '0'],
#  ['0', '0(0.00)', '0(0.00)', '쭈꾸미시스터즈', '(주)제이알인터내셔널', '11'],
#  ['2', '0', '6', '0', '384,695(0.97)', '6,521(0.02)'],
#  ['사돈팔촌목살집', '(유)원조목살집', '11', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '함양옻닭', '함양옻닭', '11'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['다담뜰 한식뷔페', '(주)다담뜰', '11', '4', '0', '0'],
#  ['0', '1,289,095(3.24)', '8,484(0.02)', '돌리고제주도야지', '돌리고푸드시스템', '11'],
#  ['5', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['제주도야지판', '(주)이바돔', '11', '7', '0', '0'],
#  ['0', '457,608(1.15)', '4,273(0.01)', '꼬기냉면', ' (주)꼬기냉면', '11'],
#  ['3', '0', '0', '0', '196,342(0.49)', '9,592(0.02)'],
#  ['장수본가해장국', '(주)장수엔터프라이즈', '11', '5', '0', '0'],
#  ['0', '374,365(0.94)', '14,974(0.04)', '놀부항아리갈비', '(주)놀부', '11'],
#  ['3', '4', '0', '1', '358,925(0.90)', '7,449(0.02)'],
#  ['도도랑', '(유)도도랑', '11', '2', '1', '0'],
#  ['1', '275,314(0.69)', '6,882(0.02)', '통뼈감자탕', '농업회사법인(주)자연식품', '11'],
#  ['1', '0', '0', '0', '156,703(0.39)', '2,997(0.01)'],
#  ['하이미트', '영진인터네셔널주식회사', '11', '0', '0', '12'],
#  ['2', '257,611(0.65)', '3,550(0.01)', '온누리장작구이', '(주)온누리푸드시스템', '11'],
#  ['0', '4', '0', '0', '716,645(1.80)', '27,028(0.07)'],
#  ['도발 0948', '공구사팔컴퍼니(주)', '11', '11', '0', '0'],
#  ['0', '146,211(0.37)', '8,376(0.02)', '족발쌀롱', '족발쌀롱', '11'],
#  ['7', '0', '0', '0', '187,596(0.47)', '7,299(0.02)'],
#  ['바우네나주곰탕', '지에프유통', '11', '8', '0', '0'],
#  ['0', '202,925(0.51)', '10,373(0.03)', '효소원 순두부와 청국장 그리고 전', '(주)효소원', '11'],
#  ['0', '0', '2', '0', '249,685(0.63)', '8,165(0.02)'],
#  ['비와별 닭갈비', '(주)두빛나래', '11', '11', '0', '0'],
#  ['0', '496,748(1.25)', '9,812(0.02)', '나주곰탕염대감', '(주)제이푸드서비스', '11'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['완도수산 이오준야채막회', '완도수산 이오준야채막회', '11', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '개정', '주식회사 동원기업', '11'],
#  ['2', '0', '0', '0', '919,098(2.31)', '10,737(0.03)'],
#  ['장혁민의 부대찌개', '오름푸드(주)', '11', '11', '0', '0'],
#  ['2', '513,004(1.29)', '12,862(0.03)', '웰미가', '(주)웰미가베스트푸드', '11'],
#  ['4', '0', '11', '3', '0(0.00)', '0(0.00)'],
#  ['제임스치즈등갈비', '(주)이프유원트', '10', '1', '0', '15'],
#  ['0', '524,374(1.32)', '51,230(0.13)', '풀잎채', '(주)풀잎채', '10'],
#  ['2', '0', '0', '0', '1,418,204(3.56)', '15,585(0.04)'],
#  ['한끼야끼', '로드다이닝(주)', '10', '6', '0', '0'],
#  ['0', '359,359(0.90)', '12,218(0.03)', '솔청면옥', '(주)이밥스', '10'],
#  ['0', '0', '2', '0', '0(0.00)', '0(0.00)'],
#  ['3대서가밀면', '3대서가', '10', '5', '0', '2'],
#  ['0', '0(0.00)', '0(0.00)', '장인원조큰손할매순대국웰빙시래기해장국', '(주)장인푸드', '10'],
#  ['0', '0', '6', '0', '890,610(2.24)', '30,500(0.08)'],
#  ['바오밥(BAOBAB)', '(주)바오밥아이엔씨', '10', '7', '0', '1'],
#  ['0', '374,678(0.94)', '16,167(0.04)', '참토우', '(주)참토우 ', '10'],
#  ['1', '0', '0', '0', '751,188(1.89)', '10,612(0.03)'],
#  ['대장부', '엠투(M2)컴퍼니', '10', '0', '0', '1'],
#  ['1', '65,100(0.16)', '2,016(0.01)', '무한명장통큰삼', '무한명장통큰삼', '10'],
#  ['10', '0', '0', '0', '311,627(0.78)', '7,732(0.02)'],
#  ['쌍다리돼지불백', '(주)성북동이야기', '10', '7', '0', '1'],
#  ['0', '0(0.00)', '0(0.00)', '최용찬의 불노리', '한성푸드, 한성컨설팅', '10'],
#  ['3', '2', '0', '1', '68,063(0.17)', '2,288(0.01)'],
#  ['전주옥', '전주옥', '10', '5', '0', '3'],
#  ['0', '128,016(0.32)', '3,264(0.01)', '현풍닭칼국수', '신칼', '10'],
#  ['7', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['보쌈마루', '(주)오리비', '10', '3', '2', '0'],
#  ['0', '344,024(0.86)', '11,065(0.03)', '미스육감', '(주)마이플랜', '10'],
#  ['1', '3', '0', '0', '477,760(1.20)', '10,858(0.03)'],
#  ['서서갈비', '(주)앤쿡', '10', '10', '0', '0'],
#  ['0', '2,013,617(5.05)', '33,560(0.08)', '이가순두부감자탕', '(주)제이에이치코리아', '10'],
#  ['10', '0', '0', '0', '56,601(0.14)', '3,652(0.01)'],
#  ['용감한형제들', '(주)용형', '10', '1', '0', '6'],
#  ['0', '124,076(0.31)', '5,749(0.01)', '코다리 밥상', '(주)올댓컴퍼니', '10'],
#  ['8', '0', '0', '0', '946,949(2.38)', '10,972(0.03)'],
#  ['울엄마 양평해장국', '주식회사 울엄마푸드', '10', '8', '0', '0'],
#  ['0', '262,592(0.66)', '5,593(0.01)', '무교동유정낙지', '(주)무교동유정낙지', '10'],
#  ['1', '0', '1', '1', '760,328(1.91)', '19,596(0.05)'],
#  ['퇘장군', '퇘장군식육축산', '10', '4', '0', '0'],
#  ['0', '160,118(0.40)', '4,187(0.01)', '주복신화 불타는막창곰장어', '청우', '9'],
#  ['0', '0', '2', '0', '0(0.00)', '0(0.00)'],
#  ['샤브홀리', '샤브홀리', '9', '2', '0', '0'],
#  ['0', '748,565(1.88)', '8,421(0.02)', '오독지글', '5독스 컴퍼니', '9'],
#  ['7', '0', '2', '3', '321,973(0.81)', '10,732(0.03)'],
#  ['개성보쌈', '(주)하나아이엔디', '9', '0', '3', '0'],
#  ['0', '353,344(0.89)', '0(0.00)', '정이품쭈꾸미', '정이품쭈꾸미', '9'],
#  ['4', '0', '0', '1', '0(0.00)', '0(0.00)'],
#  ['천상대게', '천상대게', '9', '2', '0', '5'],
#  ['4', '0(0.00)', '0(0.00)', '순흥골', '(주)델리앤', '9'],
#  ['1', '0', '1', '0', '734,148(1.84)', '17,223(0.04)'],
#  ['월선네', '(주)맛있는상상', '9', '2', '0', '0'],
#  ['1',
#   '268,981(0.68)',
#   '7,685(0.02)',
#   '봉평메밀가숯불돼지갈비',
#   '그린부농봉평종합유통,강원도봉평메밀가',
#   '9'],
#  ['0', '0', '0', '0', '204,000(0.51)', '3,948(0.01)'],
#  ['대독장', '(주)티푸드컴바인', '9', '7', '0', '0'],
#  ['1', '209,811(0.53)', '5,704(0.01)', '면채반', '(주)면채반', '9'],
#  ['3', '0', '1', '0', '551,623(1.38)', '14,254(0.04)'],
#  ['더소야소', '더소야소', '9', '0', '0', '0'],
#  ['0', '392,326(0.98)', '15,231(0.04)', '화사랑화로구이', '(주)에프엘푸드시스템', '9'],
#  ['2', '0', '0', '1', '1,605,291(4.03)', '12,629(0.03)'],
#  ['바푸리죽앤즙', '(주)비피알', '9', '3', '0', '2'],
#  ['0', '167,118(0.42)', '3,798(0.01)', '보드레족', '보드레족', '9'],
#  ['1', '0', '3', '0', '0(0.00)', '0(0.00)'],
#  ['전계능의콩나물국밥', '(주)전계능', '9', '1', '1', '0'],
#  ['0', '0(0.00)', '0(0.00)', '샤브애샐러드바', '(주)다올에프씨', '9'],
#  ['7', '1', '4', '0', '845,228(2.12)', '5,944(0.01)'],
#  ['한씨네대가추어탕', '농업회사법인(주)한씨네', '9', '0', '0', '1'],
#  ['3', '231,486(0.58)', '3,301(0.01)', '오구족발', '(주)한아름푸드', '9'],
#  ['0', '0', '4', '1', '125,865(0.32)', '4,775(0.01)'],
#  ['평창동태찌개찜', '평창동태찌개찜', '9', '1', '0', '0'],
#  ['0', '148,456(0.37)', '4,494(0.01)', '153포인츠(POINTZ)', '주식회사에스엔알푸드', '9'],
#  ['5', '0', '1', '0', '359,972(0.90)', '10,432(0.03)'],
#  ['륭림닭발', '륭림닭발', '9', '3', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '철판위에빨간쭈구미', '(주)마당쇠', '9'],
#  ['0', '2', '0', '0', '142,541(0.36)', '3,393(0.01)'],
#  ['구공탄곱창', '구공탄곱창', '9', '5', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '김부삼', '(주)거당파트너스', '9'],
#  ['7', '0', '0', '0', '807,693(2.03)', '19,181(0.05)'],
#  ['장도뚝배기', '지강에프앤비(주)', '9', '9', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '한나낙지마당', '(주)한나에프씨', '9'],
#  ['0', '0', '6', '0', '0(0.00)', '0(0.00)'],
#  ['오매족', '(주)태명푸드', '9', '0', '0', '1'],
#  ['0', '371,778(0.93)', '10,761(0.03)', '토끼정', '(주)토끼정', '9'],
#  ['8', '0', '0', '0', '2,307,724(5.79)', '17,890(0.04)'],
#  ['청정고을순대', '(주)바른랩', '9', '4', '3', '0'],
#  ['0', '62,571(0.16)', '1,912(0.00)', '김둘레순대국', '(주)둘레', '9'],
#  ['4', '0', '1', '1', '0(0.00)', '0(0.00)'],
#  ['도천진짜순대', '도천진짜순대', '9', '2', '0', '4'],
#  ['0', '220,099(0.55)', '4,438(0.01)', '더 통큰구이', '(주)위더스인터내셔날', '8'],
#  ['9', '0', '4', '0', '267,607(0.67)', '8,078(0.02)'],
#  ['땡기요', '와이엠씨푸드', '8', '6', '0', '0'],
#  ['0', '172,421(0.43)', '10,621(0.03)', '하누소', '(주)하누소푸드시스템', '8'],
#  ['1', '0', '0', '0', '1,888,341(4.74)', '10,707(0.03)'],
#  ['쿡친', '마시굿', '8', '2', '0', '0'],
#  ['0', '183,346(0.46)', '15,210(0.04)', '백년시래기', '(주)백년에프씨', '8'],
#  ['8', '0', '0', '0', '365,474(0.92)', '9,311(0.02)'],
#  ['전철우음식사랑빨강랭면', '(주)고향에프에스', '8', '0', '0', '4'],
#  ['0', '114,330(0.29)', '1,800(0.00)', '종로직화쭈꾸미', '종로푸드시스템(주)', '8'],
#  ['1', '2', '0', '0', '747,842(1.88)', '8,903(0.02)'],
#  ['덤앤덤 매운갈비찜', '대웅미트코리아', '8', '8', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '삼교리동치미막국수', '(주)삼교리', '8'],
#  ['4', '0', '0', '1', '262,446(0.66)', '5,481(0.01)'],
#  ['토고리 옛날막창 소갈비살', '주식회사 지에프코리아', '8', '8', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '79네 수육국밥', '79네 푸드컴퍼니(주)', '8'],
#  ['5', '0', '0', '0', '479,705(1.20)', '12,731(0.03)'],
#  ['신사부대찌개&품격삼겹살', '신사부대찌개&품격삼겹살', '8', '6', '0', '0'],
#  ['0', '227,174(0.57)', '6,106(0.02)', '마포주먹구이', '마포주먹구이복미끼', '8'],
#  ['0', '0', '3', '0', '80,988(0.20)', '3,620(0.01)'],
#  ['와사비', '(주)와사비네푸드', '8', '8', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '닭발싸롱', '맛있는이야기', '8'],
#  ['6', '0', '3', '2', '20,244(0.05)', '789(0.00)'],
#  ['류아저씨의화동생갈비', '(주)가연푸드', '8', '0', '3', '0'],
#  ['1', '813,430(2.04)', '11,660(0.03)', '삼곱식당', '삼곱푸드', '8'],
#  ['8', '0', '0', '0', '532,957(1.34)', '22,943(0.06)'],
#  ['본비빔밥', '본아이에프(주)', '8', '0', '0', '2'],
#  ['0', '198,356(0.50)', '12,834(0.03)', '무한샤브샤브버섯나라', '무한버섯나라', '8'],
#  ['0', '0', '2', '0', '0(0.00)', '0(0.00)'],
#  ['두부본가어묵', '후푸드', '8', '0', '0', '1'],
#  ['0', '0(0.00)', '0(0.00)', '파주닭국수', '(주)송정푸드', '8'],
#  ['8', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['소한마리몽땅무쏘', '(주)일센치', '8', '8', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '소세지야', '가야푸드', '8'],
#  ['1', '0', '2', '0', '105,426(0.26)', '8,519(0.02)'],
#  ['최용석의 뼈큰청진동해장국', '(주)뚝심푸드', '8', '0', '3', '3'],
#  ['0', '600,229(1.51)', '6,484(0.02)', '고기굽는짬장', '(주)한국창업경제연구소', '7'],
#  ['0', '0', '2', '0', '246,797(0.62)', '8,359(0.02)'],
#  ['로꼬로꼬', '로꼬로꼬', '7', '0', '1', '1'],
#  ['0', '426,702(1.07)', '11,713(0.03)', '명품청기와감자탕', '다니엘푸드', '7'],
#  ['7', '0', '0', '0', '596,829(1.50)', '17,166(0.04)'],
#  ['주박사네순대국밥', '(주)주박사네', '7', '0', '0', '1'],
#  ['0', '427,900(1.07)', '9,691(0.02)', '고을래제주흑돼지', '(주)미락에프씨', '7'],
#  ['1', '0', '0', '0', '57,900(0.15)', '988(0.00)'],
#  ['육회먹은연어', '(주)비에프푸드', '7', '2', '0', '3'],
#  ['1', '307,532(0.77)', '12,596(0.03)', '신단설렁탕', '진대푸드', '7'],
#  ['4', '0', '2', '0', '212,616(0.53)', '6,728(0.02)'],
#  ['삼훈 국민생아구찜', '(주)백경푸드시스템', '7', '0', '0', '0'],
#  ['0', '254,300(0.64)', '5,321(0.01)', '맛잡이해물천지', '(주)제이앤케이코리아', '7'],
#  ['2', '0', '0', '2', '0(0.00)', '0(0.00)'],
#  ['맵수다', '(주)리드웨이', '7', '4', '0', '2'],
#  ['2', '0(0.00)', '0(0.00)', '맵돈', '(주)매운생각', '7'],
#  ['1', '0', '0', '0', '175,493(0.44)', '6,824(0.02)'],
#  ['오라이숯불닭갈비', '(주)자연가득', '7', '0', '0', '1'],
#  ['0', '0(0.00)', '0(0.00)', '오투닭갈비', '오투닭갈비', '7'],
#  ['4', '0', '1', '0', '0(0.00)', '0(0.00)'],
#  ['생고기제작소', '생고기제작소(주)', '7', '7', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '에그파파', '(주)계림식품농업회사법인', '7'],
#  ['0', '0', '9', '1', '3,810(0.01)', '523(0.00)'],
#  ['마포통', '(주)엠지에이치', '7', '7', '0', '0'],
#  ['1', '0(0.00)', '0(0.00)', '애솔촌돼지', '애솔촌돼지', '7'],
#  ['0', '0', '2', '0', '268,096(0.67)', '12,595(0.03)'],
#  ['대구안지랑막창', '원가네푸드', '7', '5', '0', '0'],
#  ['0', '229,607(0.58)', '8,490(0.02)', '다시오고싶은집 이명숙 양평해장국', '조이식품', '7'],
#  ['0', '1', '0', '0', '204,407(0.51)', '5,203(0.01)'],
#  ['선육후면', '(주)제니스에프앤비', '7', '4', '0', '1'],
#  ['0', '647,154(1.62)', '6,398(0.02)', '장인족발608', '(주)제이엠케이에스', '7'],
#  ['4', '0', '0', '0', '307,886(0.77)', '6,540(0.02)'],
#  ['한결같은마음으로', '(주)지피에프씨', '7', '7', '0', '0'],
#  ['0', '441,897(1.11)', '11,215(0.03)', '맘스토리', '맘스토리', '7'],
#  ['4', '0', '0', '0', '75,175(0.19)', '6,264(0.02)'],
#  ['남자마늘보쌈', '(주)미스터쿡', '7', '0', '0', '0'],
#  ['0', '694,006(1.74)', '6,761(0.02)', '소싯적청춘을요리하다', '(주)소싯적청춘을요리하다', '7'],
#  ['6', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['최달포', '(주)에스지프랜차이즈', '7', '9', '0', '2'],
#  ['0', '0(0.00)', '0(0.00)', '농부애갈비', '(주)농부애푸드', '7'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['만복한쭈꾸미낙지볶음', '만복이쭈꾸미낙지볶음', '7', '1', '0', '0'],
#  ['0', '837,432(2.10)', '11,165(0.03)', '청초수물회앤섭국', '(주)청초수씨푸드', '7'],
#  ['1', '0', '1', '0', '0(0.00)', '0(0.00)'],
#  ['기사식당', '(주)현우팩토리', '7', '7', '0', '0'],
#  ['0', '341,498(0.86)', '11,711(0.03)', '사재감참숯왕소금구이', '(주)사재감', '7'],
#  ['7', '0', '0', '0', '299,221(0.75)', '6,905(0.02)'],
#  ['베이클보쌈과갈릭족발', '홍푸드', '7', '4', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '한판닭갈비', '에이치아이에프(HIF)', '7'],
#  ['5', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['놀부맑은설렁탕담다', '(주)놀부', '7', '0', '4', '0'],
#  ['1', '171,660(0.43)', '6,663(0.02)', '곱창제작소', '다니은 F&D', '7'],
#  ['7', '0', '0', '0', '348,397(0.87)', '13,254(0.03)'],
#  ['육앤샤', '디티푸드', '7', '0', '0', '3'],
#  ['0', '0(0.00)', '0(0.00)', '만만코코로', '(주)만만연구소', '6'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['빨간병아리', '빨간병아리체인유통본부', '6', '2', '0', '2'],
#  ['1', '0(0.00)', '0(0.00)', '더도이종가집돼지국밥', '(주)더도이종가집', '6'],
#  ['5', '0', '0', '0', '1,029,217(2.58)', '10,231(0.03)'],
#  ['원가네 얼큰이', '원가네푸드', '6', '1', '0', '0'],
#  ['0', '171,298(0.43)', '8,017(0.02)', '좋구먼', '(주)맛있는상상', '6'],
#  ['0', '2', '0', '0', '0(0.00)', '0(0.00)'],
#  ['반반한되야지', '(주)리오컴퍼니', '6', '4', '0', '1'],
#  ['1', '94,875(0.24)', '4,907(0.01)', '해물솥밥모랑', '푸드벤처스(주)', '6'],
#  ['0', '1', '1', '2', '532,697(1.34)', '15,591(0.04)'],
#  ['명장복집&24시명장복국', '명장복집', '6', '4', '0', '0'],
#  ['0', '452,000(1.13)', '5,650(0.01)', '박손녀의콩각시동태', '(주)이림에프앤피', '6'],
#  ['4', '0', '2', '1', '485,348(1.22)', '17,763(0.04)'],
#  ['족발한상', '(주)소다푸드', '6', '6', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '찌개애감동', '(주)맛있는상상', '6'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['쪽찌', '(주)마더푸드', '6', '6', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '콩산소콩나물국밥', '콩산소', '6'],
#  ['0', '0', '0', '0', '96,000(0.24)', '3,200(0.01)'],
#  ['무한한판8.8', '(주)조은세상에프앤씨', '6', '6', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '용문해장국', '(주)와이엠푸드', '6'],
#  ['0', '0', '4', '0', '49,072(0.12)', '1,937(0.00)'],
#  ['찜닭맨', '찜닭맨', '6', '0', '0', '1'],
#  ['0', '105,878(0.27)', '11,694(0.03)', '두거리우신탕', '두거리푸드', '6'],
#  ['1', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['한옥집김치찜', '(주)위대한식품', '6', '3', '0', '0'],
#  ['1', '1,008,045(2.53)', '20,334(0.05)', '한국밥', '(주)굳길', '6'],
#  ['2', '1', '0', '1', '508,813(1.28)', '14,607(0.04)'],
#  ['태기산더덕순대', '(주)푸드프랜', '6', '1', '0', '3'],
#  ['0', '416,417(1.05)', '12,946(0.03)', '메밀고개 시골막국수', '메밀고개푸드(주)', '6'],
#  ['0', '5', '0', '0', '0(0.00)', '0(0.00)'],
#  ['연막술', '(주)푸드리아', '6', '0', '0', '3'],
#  ['1', '507,977(1.28)', '12,671(0.03)', '세븐유 소금구이&껍데기', '(주)행운식품', '6'],
#  ['0', '0', '0', '0', '161,591(0.41)', '4,776(0.01)'],
#  ['날마다꿀갈비', '미소에프앤에스(주)', '5', '0', '0', '1'],
#  ['1', '39,437(0.10)', '590(0.00)', '전라도이야기', '전라도이야기', '5'],
#  ['3', '0', '0', '1', '0(0.00)', '0(0.00)'],
#  ['미소육화', '(주)지케이푸드', '5', '4', '0', '0'],
#  ['0', '600,747(1.51)', '6,620(0.02)', '미친고기', '미친고기', '5'],
#  ['5', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['불란다쭈꾸미', '(주)행운식품', '5', '1', '1', '0'],
#  ['0', '419,165(1.05)', '6,872(0.02)', '알쭈', '제로플러스공인중개사사무소', '5'],
#  ['5', '0', '0', '0', '197,150(0.49)', '8,961(0.02)'],
#  ['해늘찹쌀순대', '(주)해늘', '5', '2', '0', '3'],
#  ['0', '0(0.00)', '0(0.00)', '연경호킹아구해물찜', '킹아구해물찜아중점', '5'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['다깡', '다감', '5', '4', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '삼국집', '(주)에이치에스푸드', '5'],
#  ['0', '0', '2', '0', '268,647(0.67)', '9,638(0.02)'],
#  ['박대박부대찌개', '박대박', '5', '0', '0', '0'],
#  ['0', '392,764(0.99)', '16,502(0.04)', '싸가지없는갈비', '싸가지없는갈비', '5'],
#  ['5', '0', '0', '0', '308,681(0.77)', '8,725(0.02)'],
#  ['김경자소문난대구왕뿔찜', '해듬(주)', '5', '1', '0', '0'],
#  ['0', '336,727(0.85)', '4,989(0.01)', '귀품찬 불백집', '(주)곽푸드에프씨', '5'],
#  ['5', '0', '0', '1', '336,586(0.84)', '5,905(0.01)'],
#  ['황금코다리', '(주)유니쉐프', '5', '5', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '의령', '(주)의령한우국밥', '5'],
#  ['0', '1', '0', '0', '319,200(0.80)', '8,356(0.02)'],
#  ['착한전복', '(주)두둑한행복', '5', '0', '0', '0'],
#  ['0', '2,040,016(5.12)', '12,911(0.03)', '오리궁뎅이', '오리궁뎅이', '5'],
#  ['1', '0', '0', '0', '324,030(0.81)', '5,143(0.01)'],
#  ['뼈세상', '(주)뼈세상', '5', '5', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '황태장인', '(주)팀웍앤비', '5'],
#  ['5', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['뚱뚱이할머니족발보쌈', '(주)미도식품', '5', '1', '0', '5'],
#  ['0', '0(0.00)', '0(0.00)', '콩사돈', '(주)지엠푸드', '5'],
#  ['5', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['게수작', '(주)나모에프앤씨', '5', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '갈비박스', '농업회사법인(주)촌놈푸드', '5'],
#  ['2', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['부야스곱창', '(주)유앤아이컴즈', '5', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '정든낙지', '정든푸드', '5'],
#  ['0', '3', '0', '0', '0(0.00)', '0(0.00)'],
#  ['명덕총각족발', '총각푸드', '5', '5', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '느그집', '어바웃컴퍼니', '5'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['생생낙지', '(주)조마루', '5', '0', '0', '0'],
#  ['1', '0(0.00)', '0(0.00)', '다누리', '대신푸드', '5'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['배불뚝집', '유한회사 토암', '5', '0', '0', '1'],
#  ['2', '0(0.00)', '0(0.00)', '큰집아저씨', '큰집아저씨본점', '5'],
#  ['1', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['홍반장신의주찹쌀순대와감자탕', '(주)홍반장', '5', '0', '0', '0'],
#  ['0', '340,454(0.85)', '11,262(0.03)', '내림손삼계탕', '(주)세붕푸드', '5'],
#  ['1', '0', '0', '1', '293,719(0.74)', '7,244(0.02)'],
#  ['수향그릴면가여름도겨울', '제니스푸드시스템', '5', '1', '0', '0'],
#  ['1', '194,014(0.49)', '5,331(0.01)', '만송골갈비탕', '엠에스푸드', '5'],
#  ['2', '0', '0', '0', '454,158(1.14)', '6,170(0.02)'],
#  ['탐라수제갈비', '(주)한세푸드', '5', '5', '0', '0'],
#  ['0', '714,847(1.79)', '16,518(0.04)', '이마시아', '(주)돈스', '5'],
#  ['1', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['육봉달333', '(주)티아이코스모스', '5', '5', '0', '0'],
#  ['0', '491,497(1.23)', '7,123(0.02)', '전초전', '(주)더불어함께하는세상', '5'],
#  ['5', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['육당', '미소에프앤에스(주)', '5', '2', '0', '2'],
#  ['0', '94,533(0.24)', '1,759(0.00)', '고덕갈비', '고덕갈비', '5'],
#  ['1', '0', '2', '0', '0(0.00)', '0(0.00)'],
#  ['육마니 옛날전통육개장', '육마니(주)', '5', '0', '0', '0'],
#  ['2', '240,111(0.60)', '5,153(0.01)', '인기명', '(주)인에프앤씨', '5'],
#  ['1', '0', '0', '1', '679,033(1.70)', '7,414(0.02)'],
#  ['꼬독이', '(주)태사랑', '5', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '더새론갈비', '새론푸드', '5'],
#  ['2', '0', '0', '1', '0(0.00)', '0(0.00)'],
#  ['메밀골동해막국수', '(주)해살이뜰', '5', '0', '0', '2'],
#  ['1', '0(0.00)', '0(0.00)', '조선닭볶음탕', '딜리버리킹', '5'],
#  ['5', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['맷돌로만', '(주)엠에스푸드', '4', '0', '0', '1'],
#  ['0', '0(0.00)', '0(0.00)', '신곱창선생 외 1개', '코리안브라더', '4'],
#  ['4', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['임애리 와따김치찜', '임애리와따김치찜 본점', '4', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '막돼먹은막창', '(주)엠디엠', '4'],
#  ['2', '0', '1', '0', '0(0.00)', '0(0.00)'],
#  ['에브리농장', '에브리농원', '4', '2', '1', '1'],
#  ['0', '0(0.00)', '0(0.00)', '놀부유황오리', '(주)놀부', '4'],
#  ['1', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['야채꽃', '올윈푸드', '4', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '큰돈쪽쪽갈비', '큰돈쪽쪽갈비', '4'],
#  ['2', '0', '1', '0', '0(0.00)', '0(0.00)'],
#  ['왓삼', '왓삼푸드', '4', '3', '1', '0'],
#  ['0', '0(0.00)', '0(0.00)', '쭈꾸쭈꾸아', '쭈꾸쭈꾸아', '4'],
#  ['4', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['사나이창', '(주)사나이', '4', '1', '1', '1'],
#  ['0', '0(0.00)', '0(0.00)', '육수당', '(주)에이치디푸드', '4'],
#  ['4', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['서소문족발', '서소문 (주)', '4', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '무한장소', '주식회사 제이씨엠에프씨', '4'],
#  ['4', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['대통삼', '(주)모던키친컴퍼니', '4', '4', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '맵찌롱', '맵찌롱', '4'],
#  ['0', '0', '2', '0', '0(0.00)', '0(0.00)'],
#  ['육회말투아웃', '(주)수에프씨', '4', '4', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '특뿔하우스식육식당', '특뿔하우스', '4'],
#  ['4', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['산내음', '산내음식품', '4', '0', '0', '3'],
#  ['0', '0(0.00)', '0(0.00)', '88콩나물국밥', '(주)웰미가베스트푸드', '4'],
#  ['4', '0', '0', '0', '14,650(0.04)', '733(0.00)'],
#  ['대한뉴스', '(주)대한뉴스에프앤비', '4', '0', '0', '5'],
#  ['0', '0(0.00)', '0(0.00)', '안가', '(주)안가', '4'],
#  ['2', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['한동길전통감자탕', '한동길식품', '4', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '서남왕족발', '서남식품', '4'],
#  ['0', '1', '0', '0', '0(0.00)', '0(0.00)'],
#  ['이광호3일소고기국밥', '(주)광에프씨', '4', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '팔꾸이팔당닭발', '팔꾸이', '4'],
#  ['1', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['메기매운탕전문점아우라지', '(주)보릿골', '4', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '가소', '농업회사법인유한회사 가소앤누갈비', '4'],
#  ['1', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['멋진녀석들', '(주)제주돈에프씨', '4', '0', '1', '0'],
#  ['0', '0(0.00)', '0(0.00)', '원조 정우영 조방낙지', '원조 조방낙지', '4'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['하루덕', '(주)회진푸드', '4', '0', '3', '0'],
#  ['0', '0(0.00)', '0(0.00)', '정미소아리랑닭갈비', '글로벌 세종 창업연구소', '4'],
#  ['4', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['애플삼겹살', '(주)디딤', '4', '4', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '북깐', '(주)언제나', '4'],
#  ['0', '6', '0', '0', '187,106(0.47)', '5,893(0.01)'],
#  ['낭만갈비', '(주)마이플랜', '4', '4', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '대가야삼계탕', '(주)대가야', '4'],
#  ['0', '0', '0', '0', '381,748(0.96)', '5,549(0.01)'],
#  ['보승대한족발집', '보승FC', '4', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '모심 임가네 해물촌', '임가네 해물촌', '4'],
#  ['0', '0', '1', '0', '0(0.00)', '0(0.00)'],
#  ['옹헤야', '씨에프', '4', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '황칠가', '(주)에이치에스피라이프', '4'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['청춘연가', '(주)에쓰와이프랜차이즈', '4', '3', '0', '2'],
#  ['4', '0(0.00)', '0(0.00)', '장윤조가마솥국밥', '(주)아라에프엔비', '4'],
#  ['0', '5', '0', '0', '0(0.00)', '0(0.00)'],
#  ['홍구등갈비', '베리굿에프앤비', '4', '2', '1', '1'],
#  ['0', '0(0.00)', '0(0.00)', '텃밭시래기', '햇빛과 바람', '4'],
#  ['5', '0', '1', '0', '0(0.00)', '0(0.00)'],
#  ['주식회사 영동족발', '(주)영동족발', '4', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '병천순대', '농업회사법인 주식회사 병천순대', '4'],
#  ['2', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['철든놈', '주식회사 아이언랩', '4', '0', '0', '2'],
#  ['0', '0(0.00)', '0(0.00)', '철판요리포차판', '(주)와이낫', '4'],
#  ['1', '0', '0', '0', '78,976(0.20)', '6,403(0.02)'],
#  ['훔친갈비', '(주)프레쥬퀸', '4', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '전주이가네콩나물국밥', '이가네콩푸드', '4'],
#  ['4', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['퍼주네국밥족발', '(주)덤푸드', '4', '4', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '밥엔청국장', '(주)맛있는상상', '4'],
#  ['0', '0', '1', '0', '0(0.00)', '0(0.00)'],
#  ['숟가락반상 마실', '마실', '4', '4', '0', '0'],
#  ['0', '1,244,431(3.12)', '9,799(0.02)', '대한국밥', '(주)더본코리아', '4'],
#  ['1', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['황제해물보쌈', '(주)더엠퍼러', '4', '0', '0', '8'],
#  ['0', '0(0.00)', '0(0.00)', '백스비빔밥', '(주)더본코리아', '3'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['황제육회', '(주)동해의한우', '3', '0', '2', '0'],
#  ['0', '0(0.00)', '0(0.00)', '와우리장작구이', '에스엠푸드서비스', '3'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['낙지낙자(이희성무교동낙지)', 'J.F.C제일외식산업체인본부"갯벌속낙지낙자"', '3', '0', '0', '3'],
#  ['0', '0(0.00)', '0(0.00)', '육콩', '(주)육콩푸드', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['족발대장', '족발대장', '3', '3', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '문삼이', '(주)경청에프씨', '3'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['삼대족발', '다담', '3', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '고기고샵', '(주)이도에프앤씨', '3'],
#  ['1', '0', '0', '0', '743,536(1.87)', '11,865(0.03)'],
#  ['굽데이', '(주)함께하는사람들', '3', '2', '1', '0'],
#  ['1', '0(0.00)', '0(0.00)', '류재열의 명품코다리찜', '류재열의 명품코다리찜', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['해양산', '해양산', '3', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '노빠꾸', '노빠꾸 연탄석쇠구이', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['맵촌', '(주)휘둘찬푸드', '3', '0', '0', '1'],
#  ['0', '0(0.00)', '0(0.00)', '남와집', '(주)에스테드아시아', '3'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['샤브보트', '(주)채선당', '3', '3', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '다퍼주는무한리필감자탕', '다퍼무리F&B', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['옛날육개장시골촌', '(주)순희에프앤비', '3', '1', '0', '3'],
#  ['0', '0(0.00)', '0(0.00)', '육시리', '티티씨에프', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['통큰손쭈꾸미마을', '(주)하늘샘', '3', '3', '0', '1'],
#  ['0', '577,803(1.45)', '13,750(0.03)', '화산고', '(주)미도비앤케이', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['조개夜(조개야)', '조개야', '3', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '덕소숯불고기', '(주)찐스', '3'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['어만형제', '어만장어구이', '3', '3', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '더서민구이(The서민구이)', '(주)더드림에프씨', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['주순자꼼장어', '(주)수정씨푸드', '3', '0', '0', '2'],
#  ['0', '0(0.00)', '0(0.00)', '심민속촌', '에코푸드(주)', '3'],
#  ['0', '0', '0', '1', '0(0.00)', '0(0.00)'],
#  ['온누리쭈꾸미', '(주)온누리푸드시스템', '3', '0', '1', '0'],
#  ['0', '0(0.00)', '0(0.00)', '메고지고', '(주)라이스파이', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['더만소', '더푸드', '3', '0', '1', '0'],
#  ['0', '0(0.00)', '0(0.00)', '국산특허마늘곱창막창', '국산특허마늘곱창막창', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['파육장', '(주)용마을', '3', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '만권화밥', '(주)만권', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['조개꽃천지', '(주)바다드림', '3', '3', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '채소야', '채소야푸드', '3'],
#  ['0', '3', '0', '0', '0(0.00)', '0(0.00)'],
#  ['흑돈우', '(주)회진푸드', '3', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '밥하기싫은날 후루룩손칼국수', '밥하기싫은날', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['히노케', '히노케', '3', '0', '6', '3'],
#  ['0', '0(0.00)', '0(0.00)', '본우리반상', '본푸드서비스(주)', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['쿡일레븐', '(주)쿡일레븐', '3', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '킹스덮밥', '(주)더빅코리아', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['봉대박찜닭', '(주)에프씨봉대박', '3', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '돈부락', '(주)이트락', '3'],
#  ['1', '1', '0', '0', '0(0.00)', '0(0.00)'],
#  ['강남콩', '강남콩', '3', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '육사돈', '(주)육사돈', '3'],
#  ['0', '2', '0', '0', '0(0.00)', '0(0.00)'],
#  ['셰프의육개장', '(주)바인에프씨', '3', '0', '0', '2'],
#  ['0', '14,969(0.04)', '14,724(0.04)', '젠틀피그', '젠틀피그', '3'],
#  ['2', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['짝태시대', '짝태시대', '3', '3', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '이진태왕소금구이', '제이티프렌즈(주)', '3'],
#  ['2', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['봉화산설렁탕', '(주)봉화산푸드', '3', '0', '0', '0'],
#  ['1', '0(0.00)', '0(0.00)', '먹으면좋으리순대국밥1번지', '먹으면좋으리순대국밥1번지', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['대석대구찜닭', '대석대구찜닭', '3', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '배가네동태탕찜전문점', '배가네동태탕', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['신가네정읍국밥', '신가네정읍국밥', '3', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '안성파닭', '한신푸드', '3'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['강남꼬치1번가', '(주) 강남식품1번가', '3', '0', '0', '2'],
#  ['0', '0(0.00)', '0(0.00)', '쌀을품은닭', '봉산에프앤비', '3'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['육회브라더스', '토니앤컴퍼니인터내셔널', '3', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '이태리부대찌개', '(주)지니어스', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['본동네추어탕', '(주)푸드원', '3', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '티오티(TOT)', '(주)다조은푸드', '3'],
#  ['0', '0', '3', '0', '0(0.00)', '0(0.00)'],
#  ['두루애', '(주)한국창업경제연구소', '3', '0', '0', '4'],
#  ['0', '0(0.00)', '0(0.00)', '다사면(다시사랑한다면)', '빈야드(주)', '3'],
#  ['3', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['제주생선구이 올래밥상', '영어조합법인 올래씨푸드', '3', '3', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '본마야', '(주)마야에프앤에프', '3'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['닭요리전문점시골촌', '(주)순희에프앤비', '3', '3', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '수돈재', '(주)한소반', '3'],
#  ['2', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['깜디스찜닭', '(주)퓨전한식연구소 디엠', '2', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '조선육개장38', '조선38육개장', '2'],
#  ['1', '0', '0', '0', '403,524(1.01)', '8,967(0.02)'],
#  ['백정돈공장', '백정돈공장', '2', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '봄채향', '(주)이밥스', '2'],
#  ['0', '0', '3', '0', '0(0.00)', '0(0.00)'],
#  ['바른식탁', '바른연구소', '2', '2', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '족쌈베이크', '(주)토담', '2'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['술고당', '술고당', '2', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '명랑회관', '(주)명랑식품', '2'],
#  ['2', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['쭈가네', '(주)김가네', '2', '0', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '시래옥', '(주)시래옥', '2'],
#  ['0', '0', '0', '1', '0(0.00)', '0(0.00)'],
#  ['설담재', '설담재설렁탕', '2', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '리라김밥', '(주)고릴라마마스', '2'],
#  ['1', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['장충동일품 왕족발 보쌈', '(주)일품푸드', '2', '2', '0', '0'],
#  ['0', '158,000(0.40)', '20(0.00)', '조바우가마솥추어탕', '조바우가마솥추어탕', '2'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['돈불1971', '돈불', '2', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '불끈낙지', '예스람', '2'],
#  ['0', '2', '2', '0', '0(0.00)', '0(0.00)'],
#  ['류가본가', '류가본가', '2', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '미당추어탕', '(주)미당', '2'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['효소원순두부와청국장그리고찜', '(주)효소원', '2', '0', '0', '1'],
#  ['0', '0(0.00)', '0(0.00)', '하루방뒷고기', '(주)첨성대', '2'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['호구의 족발보쌈', '호구스', '2', '1', '0', '0'],
#  ['0', '0(0.00)', '0(0.00)', '소바애', '소바애부천본점', '2'],
#  ['0', '0', '0', '0', '0(0.00)', '0(0.00)'],
#  ['육칠팔', '(주)육칠팔', '2', '0', '2', '0'],
#  ...]

# %%
# Out:
# 10

# %%
html=driver.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
len(soup.find_all('td'))/6

# %%
rows = []
for row in range(int(len(soup.find_all('td'))/6)):
    row1 = []
    
    for i in range(0+(row*6), 6+(row*6)) :
        tmp = soup.find_all('td')[i].get_text()
        tmp = tmp.replace('\n','')
        tmp = tmp.replace('\t','')
        tmp = tmp.replace('\xa0','')

        row1.append(tmp)
    rows.append(row1)

# %%
data_frame = pd.DataFrame(r)
data_frame.to_csv('가나다.csv',encoding='utf-8')

# %%
pd.DataFrame(r)

# %%
html=driver.page_source
soup=BeautifulSoup(html,'html.parser')

# %%
len(soup.find_all('td'))/6
# Out:
# 326.0

# %%
rows = []
for row in range(int(len(soup.find_all('td'))/6)):
    
    row1 = []
    
    for i in range(0+(row*6), 6+(row*6)) :
        tmp = soup.find_all('td')[i].get_text()
        tmp = tmp.replace('\n','')
        tmp = tmp.replace('\t','')
        tmp = tmp.replace('\xa0','')

        row1.append(tmp)
    rows.extend(row1)

# %%
# Out:
# ['평균',
#  '-',
#  '-',
#  '4년11개월',
#  '19.7',
#  '47.3 명',
#  '이삭토스트',
#  '(주)이삭',
#  '2003.08.02',
#  '15년',
#  '754',
#  '42 명',
#  '국수나무',
#  '해피브릿지협동조합',
#  '2006.08.11',
#  '12년',
#  '490',
#  '101 명',
#  '신전떡볶이',
#  '신전푸드시스',
#  '2009.01.02',
#  '9년7개월',
#  '452',
#  '23 명',
#  '김가네김밥',
#  '(주)김가네',
#  '1996.04.05',
#  '22년4개월',
#  '415',
#  '78 명',
#  '죠스떡볶이',
#  '(주)죠스푸드',
#  '2010.01.07',
#  '8년7개월',
#  '302',
#  '26 명',
#  '김밥천국',
#  '(주)정다믄',
#  '2001.12.26',
#  '16년7개월',
#  '282',
#  '4 명',
#  '바푸리',
#  '(주)비피알',
#  '2013.05.27',
#  '5년2개월',
#  '191',
#  '48 명',
#  '용우동',
#  '(주)용마을',
#  '1999.06.01',
#  '19년2개월',
#  '166',
#  '15 명',
#  '올떡볶이',
#  '(주)지엔에스올떡',
#  '2007.01.10',
#  '11년7개월',
#  '163',
#  '12 명',
#  '신포우리만두',
#  '(유)신포우리식품',
#  '1985.05.01',
#  '33년3개월',
#  '115',
#  '89 명',
#  '명인만두',
#  '(주)명인에프엔비',
#  '2003.10.29',
#  '14년9개월',
#  '112',
#  '61 명',
#  '신참떡볶이',
#  '(주)신참에프앤씨',
#  '2005.06.01',
#  '13년2개월',
#  '110',
#  '2 명',
#  '뚱스밥버거',
#  '(주)일가인터내셔널',
#  '2013.06.01',
#  '5년2개월',
#  '110',
#  '23 명',
#  '생생돈까스',
#  '(주)에버리치에프앤비',
#  '2005.06.01',
#  '13년2개월',
#  '103',
#  '21 명',
#  '빨봉분식',
#  '(주)비엔피푸드',
#  '2011.03.14',
#  '7년5개월',
#  '103',
#  '14 명',
#  '버무리떡볶이',
#  '(주)이플푸드',
#  '2008.05.03',
#  '10년3개월',
#  '98',
#  '21 명',
#  '토마토김밥',
#  '(주)푸름에프앤에스',
#  '2010.08.01',
#  '8년',
#  '95',
#  '31 명',
#  '토스트굽는사람들',
#  '(주)케이비티',
#  '2004.03.11',
#  '14년5개월',
#  '93',
#  '7 명',
#  '두끼',
#  '(주)다른',
#  '2015.03.24',
#  '3년5개월',
#  '88',
#  '27 명',
#  '국대떡볶이',
#  '(주)국대에프앤비',
#  '2009.11.30',
#  '8년8개월',
#  '84',
#  '15 명',
#  '종로김밥',
#  '(주)제이알에프앤로지스',
#  '2006.10.10',
#  '11년10개월',
#  '81',
#  '10 명',
#  '불스떡볶이',
#  '(주) 비케이홀딩스',
#  '2014.11.01',
#  '3년9개월',
#  '80',
#  '11 명',
#  '씨앤푸드스토리 청년떡볶이',
#  '(주)씨앤푸드스토리',
#  '2013.01.03',
#  '5년7개월',
#  '74',
#  '2 명',
#  '스쿨푸드',
#  '(주)에스에프이노베이션',
#  '2009.04.30',
#  '9년3개월',
#  '73',
#  '332 명',
#  '얌샘',
#  '(주)얌샘',
#  '2006.09.01',
#  '11년11개월',
#  '70',
#  '38 명',
#  '지지고(GGGO)',
#  '(주)와이낫',
#  '2011.09.10',
#  '6년11개월',
#  '69',
#  '12 명',
#  '황기순의칼국수앤왕돈까스',
#  '(주)티에스에프엔씨',
#  '2012.03.30',
#  '6년4개월',
#  '68',
#  '21 명',
#  '역전우동0410',
#  '(주)더본코리아',
#  '2012.04.30',
#  '6년3개월',
#  '67',
#  '173 명',
#  '명동할머니국수',
#  '(주)봉원에프앤비',
#  '2012.05.24',
#  '6년3개월',
#  '63',
#  '26 명',
#  '이웃집소녀떡볶이',
#  '이웃집소녀쉐프',
#  '2013.09.01',
#  '4년11개월',
#  '62',
#  '2 명',
#  '신불떡볶이',
#  '신불식품',
#  '2014.03.05',
#  '4년5개월',
#  '59',
#  '1 명',
#  '김밥나라',
#  '(주)엠지에프앤씨',
#  '2003.12.24',
#  '14년8개월',
#  '59',
#  '3 명',
#  '수유리우동집',
#  '(주)물과소금',
#  '2014.01.10',
#  '4년7개월',
#  '58',
#  '5 명',
#  '김밥천국',
#  '나누리프랜차이즈',
#  '2007.05.30',
#  '11년2개월',
#  '52',
#  '1 명',
#  '만복국수집',
#  '(주)은혜푸드',
#  '2007.09.15',
#  '10년11개월',
#  '52',
#  '6 명',
#  '킹콩떡볶이',
#  '이심전심(주)',
#  '2013.06.17',
#  '5년2개월',
#  '50',
#  '10 명',
#  '틈새라면',
#  '(주)틈새상사',
#  '2002.11.28',
#  '15년8개월',
#  '50',
#  '3 명',
#  '신떡',
#  '(주)신화에프앤비',
#  '2001.10.16',
#  '16년10개월',
#  '50',
#  '2 명',
#  '김밥킹',
#  '(주)아이윈엔터프라이즈',
#  '2015.03.04',
#  '3년5개월',
#  '44',
#  '16 명',
#  '북문로떡볶이',
#  '(주)북문로키친',
#  '2013.11.11',
#  '4년9개월',
#  '43',
#  '14 명',
#  '공수간',
#  '(주)놀부',
#  '2012.09.12',
#  '5년11개월',
#  '43',
#  '311 명',
#  '씨앗호떡',
#  '(주)에스엔인더스트리',
#  '2013.05.01',
#  '5년3개월',
#  '42',
#  '11 명',
#  '걸작떡볶이',
#  '(주)위드인푸드',
#  '2014.03.11',
#  '4년5개월',
#  '42',
#  '14 명',
#  '꾼떡',
#  '(주)트로이',
#  '2008.08.17',
#  '10년',
#  '41',
#  '6 명',
#  '로봇김밥',
#  '(주)로봇에프앤비',
#  '2014.03.01',
#  '4년5개월',
#  '38',
#  '15 명',
#  '밥맛나는세상',
#  '(주)소디프비앤에프',
#  '2015.04.30',
#  '3년3개월',
#  '37',
#  '189 명',
#  '아리가또맘마',
#  '(주)트렌차이즈',
#  '2011.03.28',
#  '7년4개월',
#  '37',
#  '14 명',
#  '나드리김밥',
#  '(주)나드리에프에스',
#  '2013.10.01',
#  '4년10개월',
#  '35',
#  '5 명',
#  '깨순이김밥',
#  '(유)대성물류',
#  '2004.01.28',
#  '14년6개월',
#  '31',
#  '6 명',
#  '송촌꼬마김밥',
#  '송촌꼬마김밥',
#  '2015.10.15',
#  '2년10개월',
#  '31',
#  '3 명',
#  '요런떡볶이',
#  '(주)자연애몸',
#  '2009.02.12',
#  '9년6개월',
#  '31',
#  '6 명',
#  '디델리',
#  '(주)디엔에프씨',
#  '2004.10.15',
#  '13년10개월',
#  '30',
#  '2 명',
#  '웁스떡볶이',
#  '웁스에프앤씨',
#  '2013.04.01',
#  '5년4개월',
#  '29',
#  '2 명',
#  '찰스숯불김밥',
#  '(주)찰스푸드',
#  '2013.02.21',
#  '5년6개월',
#  '29',
#  '15 명',
#  '울타리없는만두집',
#  '제이앤푸드',
#  '2015.03.13',
#  '3년5개월',
#  '29',
#  '0 명',
#  '빨간망토',
#  '(주)일가인터내셔널',
#  '2015.09.01',
#  '2년11개월',
#  '29',
#  '23 명',
#  '나는 조선의 떡볶이다',
#  '이노레시피',
#  '2014.12.22',
#  '3년8개월',
#  '29',
#  '2 명',
#  '밀크밥버거',
#  '(주)오색만찬',
#  '2013.04.01',
#  '5년4개월',
#  '28',
#  '62 명',
#  '소문난공주떡볶이',
#  '아이제이(IJ)푸드',
#  '2009.11.14',
#  '8년9개월',
#  '28',
#  '1 명',
#  '새벽길빨간오뎅',
#  '설화식품',
#  '2003.08.16',
#  '15년',
#  '26',
#  '5 명',
#  '델리웨건와작',
#  '(주)모음',
#  '2012.01.07',
#  '6년7개월',
#  '26',
#  '149 명',
#  '신만용 신가네매운떡볶이',
#  '신만용 신가네매운떡볶이',
#  '2014.03.14',
#  '4년5개월',
#  '25',
#  '1 명',
#  '얌스',
#  '(주)새모양에프앤비',
#  '2009.12.17',
#  '8년8개월',
#  '25',
#  '12 명',
#  '서가원김밥',
#  '(주)오색만찬',
#  '2014.03.10',
#  '4년5개월',
#  '23',
#  '62 명',
#  '눈물떡볶이',
#  '(주)눈물패밀리',
#  '2016.08.01',
#  '2년',
#  '23',
#  '9 명',
#  '스쿨스토어',
#  '(주)스쿨스토어',
#  '2011.04.27',
#  '7년3개월',
#  '23',
#  '12 명',
#  '오정은A김밥',
#  '(주)오정은',
#  '2014.09.30',
#  '3년10개월',
#  '22',
#  '13 명',
#  '보용만두',
#  '(주)보용에프앤씨',
#  '2008.08.25',
#  '10년',
#  '22',
#  '10 명',
#  '라스타',
#  '(주)마스타브렌드코리아',
#  '2015.05.01',
#  '3년3개월',
#  '20',
#  '11 명',
#  '채다올김밥',
#  '다올에프엔씨',
#  '2014.01.01',
#  '4년7개월',
#  '20',
#  '1 명',
#  '몬나니떡볶이',
#  '(주)몬스푸드',
#  '2015.06.01',
#  '3년2개월',
#  '20',
#  '6 명',
#  '왕순이 주먹밥 김밥',
#  '(주)왕순이',
#  '2013.05.05',
#  '5년3개월',
#  '20',
#  '5 명',
#  '영심이떡볶이앤김밥',
#  '(주)아름드리',
#  '2013.04.15',
#  '5년4개월',
#  '20',
#  '11 명',
#  '삼청동궁물떡볶이',
#  '(주)삼청동에프앤씨',
#  '2014.04.30',
#  '4년3개월',
#  '19',
#  '4 명',
#  '내고향냉면만두',
#  '고석환손만두',
#  '2011.03.09',
#  '7년5개월',
#  '19',
#  '4 명',
#  '고수라',
#  '고수라김밥 호남지사',
#  '2016.11.17',
#  '1년9개월',
#  '19',
#  '1 명',
#  '초읍만두',
#  '초읍만두',
#  '2015.07.01',
#  '3년1개월',
#  '19',
#  '5 명',
#  '애플김밥',
#  '(주)애플김밥',
#  '2010.11.05',
#  '7년9개월',
#  '18',
#  '7 명',
#  '반장떡볶이',
#  '(주)반장푸드',
#  '2014.04.01',
#  '4년4개월',
#  '18',
#  '7 명',
#  '가마솥김밥',
#  '(주)도시방앗간',
#  '2014.06.20',
#  '4년2개월',
#  '18',
#  '4 명',
#  '더돈까스(the돈까스)',
#  '에그트리',
#  '2014.02.01',
#  '4년6개월',
#  '18',
#  '3 명',
#  '석관동 떡볶이',
#  '오리엔트 푸드',
#  '2015.09.05',
#  '2년11개월',
#  '18',
#  '18 명',
#  '바울아저씨',
#  '(주)바울코리아',
#  '2013.12.05',
#  '4년8개월',
#  '18',
#  '4 명',
#  '오떡',
#  '(주)에이치앤비푸드',
#  '2013.10.04',
#  '4년10개월',
#  '18',
#  '2 명',
#  '신천할매떡볶이',
#  '신천할매떡볶이',
#  '1998.02.01',
#  '20년6개월',
#  '17',
#  '6 명',
#  '신탕국물떡볶이',
#  '신탕국물떡볶이',
#  '2014.03.17',
#  '4년5개월',
#  '17',
#  '0 명',
#  '불볶이와튀김범벅',
#  '칠사푸드',
#  '2009.10.02',
#  '8년10개월',
#  '17',
#  '1 명',
#  '오별난멸치국수',
#  '(주)누들앤푸드',
#  '2015.06.29',
#  '3년1개월',
#  '17',
#  '6 명',
#  '성경만두요리전문점',
#  '(주)성경에프앤에스',
#  '2014.07.21',
#  '4년1개월',
#  '17',
#  '5 명',
#  '미정국수0410',
#  '(주)더본코리아',
#  '2009.09.24',
#  '8년11개월',
#  '17',
#  '173 명',
#  '으니의수라간',
#  '(주)원스에프엔비',
#  '2013.01.14',
#  '5년7개월',
#  '17',
#  '7 명',
#  '응급실국물떡볶이',
#  '(주)금해코리아',
#  '2014.12.13',
#  '3년8개월',
#  '17',
#  '7 명',
#  '김피라(kimpira)',
#  '(주)솔트앤슈가',
#  '2015.06.11',
#  '3년2개월',
#  '17',
#  '18 명',
#  '심할머니안흥찐빵만두',
#  '어우리',
#  '2016.04.10',
#  '2년4개월',
#  '17',
#  '1 명',
#  '마리짱',
#  '(주)삼봉',
#  '2014.10.01',
#  '3년10개월',
#  '16',
#  '9 명',
#  '뽀뚜루까아저씨',
#  '(주)뽀뚜루까에프엔비',
#  '2001.05.01',
#  '17년3개월',
#  '16',
#  '7 명',
#  '목동수제돈가스',
#  '서준식품',
#  '2015.10.10',
#  '2년10개월',
#  '16',
#  '1 명',
#  '레드썬',
#  '(주)제이케이푸드',
#  '2010.08.01',
#  '8년',
#  '16',
#  '3 명',
#  '남천할매떡볶이',
#  '(주)남천에프앤비',
#  '2010.11.05',
#  '7년9개월',
#  '15',
#  '19 명',
#  '마포만두',
#  '(주)다우림푸드',
#  '2010.04.12',
#  '8년4개월',
#  '15',
#  '16 명',
#  '참숯불닭발불떡볶이',
#  '(주)다윈에프앤피',
#  '2014.06.13',
#  '4년2개월',
#  '15',
#  '4 명',
#  '사나이김밥',
#  '(주)사나이',
#  '2014.07.08',
#  '4년1개월',
#  '14',
#  '2 명',
#  '우럼마왕만두',
#  '우럼마에프앤디',
#  '2010.10.01',
#  '7년10개월',
#  '14',
#  '1 명',
#  '수김밥',
#  '손수푸드',
#  '2015.05.15',
#  '3년3개월',
#  '14',
#  '7 명',
#  '고릴라버거&컵밥',
#  '고릴라버거',
#  '2015.12.01',
#  '2년8개월',
#  '14',
#  '1 명',
#  '먹쉬돈나',
#  '(주)빅바이트에프엔비',
#  '2006.12.01',
#  '11년8개월',
#  '14',
#  '10 명',
#  '분식의신 분신',
#  '(주)에스지푸드',
#  '2015.01.14',
#  '3년7개월',
#  '13',
#  '9 명',
#  '소담비빔국수',
#  '(주)태강에프앤씨',
#  '2009.11.30',
#  '8년8개월',
#  '13',
#  '6 명',
#  '신화신가네매운떡볶이',
#  '신화',
#  '2010.12.10',
#  '7년8개월',
#  '13',
#  '4 명',
#  '호봉토스트위치',
#  '(주)호봉푸드시스템',
#  '2005.05.21',
#  '13년3개월',
#  '13',
#  '4 명',
#  '소문난왕만두찐빵',
#  '소문난식품',
#  '2007.03.10',
#  '11년5개월',
#  '13',
#  '15 명',
#  '불탕국물떡볶이',
#  '불탕국물떡볶이',
#  '2015.04.03',
#  '3년4개월',
#  '12',
#  '1 명',
#  '모범떡볶이 1976',
#  '(주)우진케이티에스',
#  '2014.11.25',
#  '3년9개월',
#  '12',
#  '2 명',
#  '우리동네면반장',
#  '(주)우리동네에프앤비',
#  '2013.11.01',
#  '4년9개월',
#  '12',
#  '7 명',
#  '홍연자명품김밥',
#  '홍연자창업센터',
#  '2010.10.26',
#  '7년9개월',
#  '12',
#  '2 명',
#  '정성한줄',
#  '(주)해밀코리아',
#  '2015.07.05',
#  '3년1개월',
#  '12',
#  '4 명',
#  '단오방',
#  '(주)단오푸드',
#  '2014.10.01',
#  '3년10개월',
#  '12',
#  '3 명',
#  '동떡 동대문매운떡볶이',
#  '동대문떡볶이 동떡',
#  '2014.07.15',
#  '4년1개월',
#  '11',
#  '1 명',
#  '고고즉석떡볶이',
#  '(주)고고푸드',
#  '2013.04.05',
#  '5년4개월',
#  '11',
#  '2 명',
#  '부송국수',
#  '부송푸드',
#  '2009.06.04',
#  '9년2개월',
#  '11',
#  '4 명',
#  '뿅떡',
#  '본가경',
#  '2012.12.10',
#  '5년8개월',
#  '11',
#  '1 명',
#  '더바스켓',
#  '(주)성하식품',
#  '2014.09.01',
#  '3년11개월',
#  '11',
#  '3 명',
#  '엄청난떡볶이',
#  '엄청난떡볶이',
#  '2014.04.01',
#  '4년4개월',
#  '11',
#  '1 명',
#  '삼화푸드몰',
#  '삼화식품',
#  '1997.05.01',
#  '21년3개월',
#  '11',
#  '8 명',
#  '보영만두',
#  '(주)보영',
#  '2008.01.30',
#  '10년6개월',
#  '10',
#  '9 명',
#  '오백국수',
#  '오백제작소',
#  '2015.10.01',
#  '2년10개월',
#  '10',
#  '1 명',
#  '셰프의돈까스',
#  '이든푸드그룹',
#  '2017.04.16',
#  '1년4개월',
#  '10',
#  '0 명',
#  '효형제돈까스',
#  '효브라더스',
#  '2015.05.25',
#  '3년3개월',
#  '10',
#  '1 명',
#  '병규돈가스',
#  '(주)병규돈가스',
#  '2012.02.26',
#  '6년5개월',
#  '10',
#  '4 명',
#  '크레이지떡',
#  '(주)참에프앤디',
#  '2008.10.02',
#  '9년10개월',
#  '10',
#  '5 명',
#  '차차',
#  '(주)차차',
#  '2016.02.10',
#  '2년6개월',
#  '10',
#  '5 명',
#  '원빙고떡볶이',
#  '다보유통',
#  '2013.02.18',
#  '5년6개월',
#  '10',
#  '1 명',
#  '하나돈까스',
#  '(주)파나',
#  '2008.06.01',
#  '10년2개월',
#  '9',
#  '13 명',
#  '홍쌤떡볶이',
#  '홍성민쌤 떡볶이',
#  '2014.10.01',
#  '3년10개월',
#  '9',
#  '1 명',
#  '떡볶이삼촌',
#  '엉클푸드',
#  '2012.01.01',
#  '6년7개월',
#  '9',
#  '1 명',
#  '달떡떡볶이파는사람들',
#  '씨앤피푸드',
#  '2015.05.11',
#  '3년3개월',
#  '9',
#  '2 명',
#  '아딸',
#  '(주)아딸',
#  '2015.10.20',
#  '2년10개월',
#  '8',
#  '5 명',
#  '바른면집',
#  '(주)치즈명가',
#  '2016.08.30',
#  '1년11개월',
#  '8',
#  '8 명',
#  '구윤희 따뜻한밥상 김밥일번지',
#  '(주)금환식품',
#  '2015.04.27',
#  '3년3개월',
#  '8',
#  '21 명',
#  '릴라밥집',
#  '릴라식품',
#  '2011.12.26',
#  '6년7개월',
#  '8',
#  '4 명',
#  '파더스김밥',
#  '(주)미셰프',
#  '2015.03.12',
#  '3년5개월',
#  '7',
#  '2 명',
#  '이여사나무김밥',
#  '(주)다온코리아',
#  '2013.09.25',
#  '4년11개월',
#  '7',
#  '3 명',
#  '맹구분식',
#  '(주)상향평준화',
#  '2015.12.09',
#  '2년8개월',
#  '7',
#  '2 명',
#  '삐사감김밥',
#  '삐사감김밥',
#  '2014.08.10',
#  '4년',
#  '7',
#  '6 명',
#  '신호탕떡볶이',
#  '미호푸드',
#  '2014.05.29',
#  '4년2개월',
#  '7',
#  '1 명',
#  '바로먹는 풀코스 ',
#  '(주)바풀(BAPOOL)',
#  '2013.07.24',
#  '5년1개월',
#  '7',
#  '4 명',
#  '분식제일가',
#  '(주)쿡앤리빙',
#  '2016.04.27',
#  '2년3개월',
#  '7',
#  '13 명',
#  '우리동네 국수집',
#  '(주)봉화산푸드',
#  '2015.06.01',
#  '3년2개월',
#  '7',
#  '9 명',
#  '추억의국민학교떡볶이',
#  '(주)팔도에프씨',
#  '2015.04.01',
#  '3년4개월',
#  '7',
#  '5 명',
#  '흥남부두',
#  '브라더식품',
#  '2015.04.30',
#  '3년3개월',
#  '7',
#  '8 명',
#  '리김밥',
#  '(주)바인인터내셔날',
#  '2015.05.25',
#  '3년3개월',
#  '7',
#  '14 명',
#  '다다믄충무김밥',
#  '다다믄충무김밥',
#  '2013.06.25',
#  '5년2개월',
#  '6',
#  '1 명',
#  '안양돈까스',
#  '에버그린',
#  '2016.08.03',
#  '2년',
#  '6',
#  '2 명',
#  '또뽀끼야',
#  '또뽀끼야',
#  '2011.11.16',
#  '6년9개월',
#  '6',
#  '1 명',
#  '엉클통김밥',
#  '(주)통에프앤씨',
#  '2013.04.01',
#  '5년4개월',
#  '6',
#  '4 명',
#  '승아의기묘한떡볶이',
#  '기묘한F&B',
#  '2016.05.30',
#  '2년2개월',
#  '6',
#  '2 명',
#  '여러분식',
#  '(주)미도비앤케이',
#  '2015.07.04',
#  '3년1개월',
#  '6',
#  '3 명',
#  '셰프의국수전',
#  '(주)바인에프씨',
#  '2011.03.08',
#  '7년5개월',
#  '6',
#  '6 명',
#  '인정국물떡볶이',
#  '두레푸드',
#  '2016.04.21',
#  '2년4개월',
#  '6',
#  '1 명',
#  'LA김밥',
#  '(주)한국창업경제연구소',
#  '2015.05.18',
#  '3년3개월',
#  '6',
#  '11 명',
#  '홍코너',
#  '(주)더프랜즈에프앤비',
#  '2014.12.02',
#  '3년8개월',
#  '6',
#  '3 명',
#  '임대표',
#  '(주)대표컴퍼니',
#  '2016.01.12',
#  '2년7개월',
#  '6',
#  '1 명',
#  '돈호야',
#  '(주)퍼스트에이엔티',
#  '2010.11.01',
#  '7년9개월',
#  '5',
#  '34 명',
#  '촌빨떡볶이',
#  '촌빨떡볶이',
#  '2014.03.07',
#  '4년5개월',
#  '5',
#  '1 명',
#  '땡벌딜리버리',
#  '너랑나랑',
#  '2015.11.23',
#  '2년9개월',
#  '5',
#  '1 명',
#  '불땡국수',
#  '(주)착한푸드',
#  '2016.03.23',
#  '2년5개월',
#  ...]

# %%
data_frame = pd.DataFrame(r)
data_frame.to_csv('가나다.csv',encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d90ebc527a60> in <module>()
# ----> 1 data_frame = pd.DataFrame(r)
#       2 data_frame.to_csv('가나다.csv',encoding='utf-8')
#
# NameError: name 'r' is not defined

# %%
pd.DataFrame(r)

# %%
rows

# %%
url = list1[0]
html = urlopen(url)
soup = BeautifulSoup(html,'html.parser')

# %%
#가맹본부 일반 현황
row1=[]
for i in range(0,6) :
    tmp = soup.find_all('td')[i].get_text()
#     tmp1 = tmp.split('\r')[1]    
    tmp = tmp.replace('\n','')
    tmp = tmp.replace('\t','')
    tmp = tmp.replace('\xa0','')
    if tmp == '' :
        tmp = tmp.split('\r')[2]
        tmp = tmp.replace('\n','')
        tmp = tmp.replace('\t','')     
    row1.append(tmp)

# %%
row1

# %%
#주소, 사업자유형, 법인등록번호, 사업자등록번호
row2=[]
for i in range(12,16) :
    tmp = soup.find_all('td')[i].get_text()
    tmp1 = tmp.split('\r')[1]    
    tmp1 = tmp1.replace('\n','')
    tmp1 = tmp1.replace('\t','')
    tmp1 = tmp1.replace('\xa0','')
    if tmp1 == '' :
        tmp1 = tmp.split('\r')[2]
        tmp1 = tmp1.replace('\n','')
        tmp1 = tmp1.replace('\t','')
        tmp1 = tmp1.replace('\xa0','')
    row2.append(tmp1)

# %%
#가맹본부 재무상황
row3=[]
for i in range(16,40) :
    tmp = soup.find_all('td')[i].get_text()
    if tmp == '' :
        row3.append(tmp)
        continue
    try :
        tmp1 = tmp.split('\r')[1]    
    except : 
        tmp1 = tmp
    tmp1 = tmp1.replace('\n','')
    tmp1 = tmp1.replace('\t','')
    if tmp1 == '' :
        tmp1 = tmp.split('\r')[2]
        tmp1 = tmp1.replace('\n','')
        tmp1 = tmp1.replace('\t','')    
    row3.append(tmp1)

# %%
#가맹사업 임직원수, 가맹본부 브랜드 및 가맹사업 계열사 수, 가맹사업 개시일
row4=[]
for i in range(40,46) :
    tmp = soup.find_all('td')[i].get_text()
    if tmp == '' :
        row4.append(tmp)
        continue
    try :
        tmp1 = tmp.split('\r')[1]    
    except : 
        tmp1 = tmp
    tmp1 = tmp1.replace('\n','')
    tmp1 = tmp1.replace('\t','')
    if tmp1 == '' :
        tmp1 = tmp.split('\r')[2]
        tmp1 = tmp1.replace('\n','')
        tmp1 = tmp1.replace('\t','')    
    row4.append(tmp1)
row4

# %%
#그외
row5=[]
for i in range(46,len(soup.find_all('td'))) :
    tmp = soup.find_all('td')[i].get_text()
    tmp = tmp.replace('\n','')
    tmp = tmp.replace('\t','')
    tmp = tmp.replace('\r','')
    tmp = tmp.replace('\xa0','')    
    row5.append(tmp)
row5
