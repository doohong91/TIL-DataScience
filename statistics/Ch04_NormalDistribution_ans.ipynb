# %% [markdown]
# ### Task
# 1. Import numpy, scipy.stats, matplotlib.pyplot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stat
import math
# %matplotlib inline

# %% [markdown]
# ### Task
# 1. Generate 100 random numbers and 100 normally distributed random numbers. And call them data_1 and data_2, respectively.
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.rand.html
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html
#
# 2. Seed the random number generator. https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
np.random.seed(34)
data_1 = np.random.rand(100)
data_2 = np.random.randn(100)

# %% [markdown]
# ### Task
# 1. Find mean and std. dev.
#
# ##### Expected outcome (actual values may be different.)
#
# mean of data_1: -0.03
#
# std.dev of data_1: 0.30
#
# mean of data_2: -0.00
#
# std.dev of data_2: 0.91

# %%
print('mean of data_1:%.2f'%np.mean(data_1))
print('std.dev of data_1:%.2f'%np.std(data_1))
print('mean of data_2:%.2f'%np.mean(data_2))
print('std.dev of data_2:%.2f'%np.std(data_2))
# Out:
# mean of data_1:0.51
# std.dev of data_1:0.32
# mean of data_2:0.16
# std.dev of data_2:1.00

# %% [markdown]
# ## Visual Normality Check
# ## 1. Histogram
# ### Task
# 1. Draw a histogram for each data set.
# 2. Check if any of them is normally distributed.
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

# %%
# histogram plot
plt.figure(figsize = (8,8))
plt.subplot(2,1,1)
plt.hist(data_1)
plt.scatter(data_1,stat.norm.pdf(data_1)*40)
plt.subplot(2,1,2)
plt.hist(data_2)
plt.scatter(data_2,stat.norm.pdf(data_2)*60)
plt.show()
# probability density function

# %% [markdown]
# ## 2. q-q plot
# ### Task
# 1. Import qqplot.
#
# http://www.statsmodels.org/dev/generated/statsmodels.graphics.gofplots.qqplot.html
#
# 2. qqplot them.
# 3. See what happens when sample sizes change for each.

# %%
from statsmodels.graphics.gofplots import qqplot
qqplot(data_1,line='s')
qqplot(data_2,line='s')

# %% [markdown]
# ## Statistical Test
# ## 1. shapiro()
#
# ### Task
# 1. shapiro() them both and compare.
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html
#
# ##### Expected outcome (actual values may be different.)
#
# stat_1: 0.9409, p_1: 0.0002
#
# stat_2: 0.9887, p_2: 0.5616
#
# For data_1 :
#
# Sample does not look Gaussian.
#
# For data_2 :
#
# It can be said that it is normally distributed.

# %%
print('stat_1: %.4f, p_1: %.4f'%(stat.shapiro(data_1)))
print('stat_2: %.4f, p_2: %.4f'%(stat.shapiro(data_2)))
# Out:
# stat_1: 0.9154, p_1: 0.0000
# stat_2: 0.9868, p_2: 0.4211

# %% [markdown]
# ## 2. normaltest()
# ### Task
# 1. normaltest() them both and compare. https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html
#
# ##### Expected outcome
#
# stat_1: 49.4264, p_1: 0.0000
#
# stat_2: 0.9779, p_2: 0.6133
#
# For data_1:
#
# Sample does not look Gaussian.
#
# For data_2 :
#
# It can be said that it is normally distributed.

# %%
print('stat_1: %.4f, p_1: %.4f'%(stat.normaltest(data_1)))
print('stat_2: %.4f, p_2: %.4f'%(stat.normaltest(data_2)))
# Out:
# stat_1: 127.4304, p_1: 0.0000
# stat_2: 1.4351, p_2: 0.4880

# %% [markdown]
# ## 3. anderson()
# ### Task
# 1. anderson() them both and compare. https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.anderson.html
#
# ##### Expected outcome
#
# data_1: Sample does not look Gaussian.
#
# data_1: Sample does not look Gaussian.
#
# data_1: Sample does not look Gaussian.
#
# data_1: Sample does not look Gaussian.
#
# data_1: Sample does not look Gaussian.
#
# data_2: It can be said that it is normally distributed.
#
# data_2: It can be said that it is normally distributed.
#
# data_2: It can be said that it is normally distributed.
#
# data_2: It can be said that it is normally distributed.
#
# data_2: It can be said that it is normally distributed.

# %%
stat_1, critical_level_1, sig_level_1 = stat.anderson(data_1)
stat_2, critical_level_2, sig_level_2 = stat.anderson(data_2)

for i in range(len(critical_level_1)):
    if stat_1 < critical_level_1[i]:
        print('ok')
    else:
        print('beep')
        
for i in range(len(critical_level_2)):
    if stat_2 < critical_level_2[i]:
        print('ok')
    else:
        print('beep')
# Out:
# beep
# beep
# beep
# beep
# beep
# ok
# ok
# ok
# ok
# ok
